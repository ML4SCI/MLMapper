# %%
#expand cell width to 100%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#import pandas 
import pandas as pd
#import numpy
import numpy as np

# %%
#set the address of the dataframe containing the pre-processed dataset
dataFramePickleAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Dataset/GRSFiveDegreeSectionPreProcessedDataset.pkl"

# %%
#read the dataframe
dataframe=pd.read_pickle(dataFramePickleAddress)

# %%
#print the dataframe
dataframe
# Out:
#       Max Lat per section  Min Lat per section  Max Lon per section  \
# 0                   -87.5                -90.0                180.0
# 1                   -82.5                -87.5               -135.0
# 2                   -82.5                -87.5                -90.0
# 3                   -82.5                -87.5                -45.0
# 4                   -82.5                -87.5                  0.0
# ...                   ...                  ...                  ...
# 1785                 87.5                 82.5                 45.0
# 1786                 87.5                 82.5                 90.0
# 1787                 87.5                 82.5                135.0
# 1788                 87.5                 82.5                180.0
# 1789                 90.0                 87.5                180.0
#
#       Min Lon per section  No. of spectra per section  \
# 0                  -180.0                        7002
# 1                  -180.0                        1599
# 2                  -135.0                        1940
# 3                   -90.0                        1818
# 4                   -45.0                        1855
# ...                   ...                         ...
# 1785                  0.0                        1748
# 1786                 45.0                        2035
# 1787                 90.0                        1903
# 1788                135.0                        1902
# 1789               -180.0                        7294
#
#       Total active time per section  \
# 0                     215153.707937
# 1                      49113.391313
# 2                      59600.854365
# 3                      55864.552890
# 4                      57007.157885
# ...                             ...
# 1785                   53653.126808
# 1786                   62483.348769
# 1787                   58474.988092
# 1788                   58399.244640
# 1789                  223993.416783
#
#                                          Summed Spectra  \
# 0     [270112.3731329723, 44221.71628033137, 45327.9...
# 1     [101728.76450092324, 11353.802617173642, 10565...
# 2     [69004.10988058499, 13041.311258502305, 12455....
# 3     [51455.21453525051, 11348.088811988011, 11487....
# 4     [51138.233213284286, 10203.879826977849, 12005...
# ...                                                 ...
# 1785  [172204.68795185376, 12837.986652251333, 11392...
# 1786  [69631.4865040512, 13027.290796013549, 12597.1...
# 1787  [58870.11519813659, 11691.651373354718, 11794....
# 1788  [69077.49428235987, 10543.676356979646, 11999....
# 1789  [342422.3644296753, 45978.50919445278, 45791.6...
#
#                                      Normalized Spectra  \
# 0     [75.32634479500912, 12.332127585726989, 12.640...
# 1     [124.27824075904886, 13.87051756806718, 12.906...
# 2     [69.4662289143658, 13.12864863838364, 12.53878...
# 3     [55.264254565457236, 12.188146033430378, 12.33...
# 4     [53.82296024948041, 10.739577490433051, 12.635...
# ...                                                 ...
# 1785  [192.57556626933405, 14.356650673799725, 12.73...
# 1786  [66.8640409410214, 12.509531949810704, 12.0964...
# 1787  [60.40543191435932, 11.996566485773727, 12.102...
# 1788  [70.97094632772614, 10.832684314943478, 12.328...
# 1789  [91.72297186611817, 12.316034066037092, 12.265...
#
#                                  Log Normalized Spectra  Aluminum  ...  \
# 0     [1.8769468938381042, 1.0910380092016139, 1.101...    15.151  ...
# 1     [2.0943950968999223, 1.1420926667518603, 1.110...    13.394  ...
# 2     [1.8417737231418783, 1.118220025472807, 1.0982...    13.634  ...
# 3     [1.742444316396172, 1.085937649122431, 1.09122...    14.642  ...
# 4     [1.7309675801735431, 1.030987195964759, 1.1015...    14.030  ...
# ...                                                 ...       ...  ...
# 1785  [2.2846011835800297, 1.1570531332525222, 1.105...    14.908  ...
# 1786  [1.8251926197192418, 1.0972410606592737, 1.082...    14.201  ...
# 1787  [1.781075993991352, 1.07905696524328, 1.082869...    14.718  ...
# 1788  [1.8510805961570183, 1.0347360871623914, 1.090...    15.137  ...
# 1789  [1.962478117625136, 1.0904708814873694, 1.0887...    15.185  ...
#
#       Magnesium  Oxygen  Potassium  Silicon  Thorium  Titanium  Uranium  \
# 0        3.5168  45.289     299.99   20.793  0.46453   0.17034  0.17684
# 1        4.2240  45.529     376.77   22.029  0.65727   0.11806  0.14017
# 2        3.5352  44.660     375.20   20.907  0.59783   0.16417  0.25209
# 3        3.6490  44.706     255.60   20.687  0.44024   0.21359  0.15456
# 4        3.4253  44.777     299.84   20.930  0.41695   0.00000  0.17853
# ...         ...     ...        ...      ...      ...       ...      ...
# 1785     4.8716  44.940     935.92   20.180  1.65770   0.11112  0.47992
# 1786     4.9509  45.074     725.37   20.989  1.47520   0.23089  0.31377
# 1787     3.5729  44.902     615.29   20.763  1.13880   0.14168  0.36836
# 1788     3.4631  45.209     534.21   20.913  0.92528   0.14485  0.24324
# 1789     4.2786  44.799     714.98   20.098  1.31050   0.14671  0.41704
#
#                             Denoised Log Scaled Spectra  \
# 0     [2.158214838616408, 2.157544331369737, 2.15556...
# 1     [2.166600464940364, 2.1658480356144825, 2.1637...
# 2     [2.1624604406884194, 2.1617557577637347, 2.159...
# 3     [2.156835106449848, 2.156137776072336, 2.15427...
# 4     [2.1550525786763455, 2.15430812063849, 2.15245...
# ...                                                 ...
# 1785  [2.15549824869262, 2.1548999596086973, 2.15302...
# 1786  [2.14741575183071, 2.14686561246586, 2.1451899...
# 1787  [2.1464838830391613, 2.1458006278534687, 2.143...
# 1788  [2.1390119880861276, 2.138304773247351, 2.1364...
# 1789  [2.1479502451595986, 2.147254910678402, 2.1453...
#
#           Continuum Removed Denoised Log Scaled Spectra  \
# 0     [0.0, 0.0031096864344261066, 0.005679290051129...
# 1     [0.0, 0.0031162181188209015, 0.005685493606940...
# 2     [0.0, 0.003128077634203974, 0.0057268713902404...
# 3     [0.0, 0.0031223821127568385, 0.005761526562635...
# 4     [0.0, 0.0030380779680346803, 0.005615903444584...
# ...                                                 ...
# 1785  [0.0, 0.0031042509343501834, 0.005683791947784...
# 1786  [0.0, 0.003080477682960492, 0.0056969814199795...
# 1787  [0.0, 0.003018919479894744, 0.0055261654685280...
# 1788  [0.0, 0.0029927682042373283, 0.005525986008764...
# 1789  [0.0, 0.003031719365600205, 0.0055773123862935...
#
#      Normalized Continuum Removed Denoised Log Scaled Spectra
# 0     [0.0, 0.008732596361173385, 0.0159485365101445...
# 1     [0.0, 0.00854362748004175, 0.01558772125881830...
# 2     [0.0, 0.008671523159558032, 0.0158757881675521...
# 3     [0.0, 0.008548415452029046, 0.0157738293766423...
# 4     [0.0, 0.00860571082569534, 0.01590770269151066...
# ...                                                 ...
# 1785  [0.0, 0.008672476703310141, 0.0158790491800041...
# 1786  [0.0, 0.008773223933367814, 0.0162250465303427...
# 1787  [0.0, 0.008498570047967925, 0.0155567263862845...
# 1788  [0.0, 0.008238164470285638, 0.0152113289416292...
# 1789  [0.0, 0.008583538074052393, 0.0157907337208821...
#
# [1790 rows x 22 columns]

# %%
#create a variable epsilon, which contains a very small value that is added to all inputs and outputs to make sure no values are 0
epsilon=1e-8

# %%
#potassium
potassiumAbundances=dataframe['Potassium'].to_numpy()+epsilon
#uranium
uraniumAbundances=dataframe['Uranium'].to_numpy()+epsilon
#thorium
thoriumAbundances=dataframe['Thorium'].to_numpy()+epsilon

# %%
#create an list which contains the element names to be estimated
elementNames=[
              'Potassium',
              'Uranium',
              'Thorium']
#conver the list to a numpy array
elementNames=np.array(elementNames)

# %%
#scale the atomic mineral values between 0 and 1
potassiumAbundances=(potassiumAbundances-np.amin(potassiumAbundances))/np.ptp(potassiumAbundances)
uraniumAbundances=(uraniumAbundances-np.amin(uraniumAbundances))/np.ptp(uraniumAbundances)
thoriumAbundances=(thoriumAbundances-np.amin(thoriumAbundances))/np.ptp(thoriumAbundances)
#combine atomic abundances into a single array
atomicAbundances=np.dstack([potassiumAbundances,uraniumAbundances,thoriumAbundances])[0,:,:]

# %%
#read the pre-processed spectra as a numpy array
preprocessedSpectra=dataframe['Normalized Continuum Removed Denoised Log Scaled Spectra'].to_numpy()
#reshape the numpy array
preprocessedSpectra=np.vstack(preprocessedSpectra)+epsilon

# %%
#compute the eneergy values for each band
gain=17.8 #keV/channel
energyBands=np.arange(0,512,1)*gain

# %%
#get the index of the last relavent band
finalRelaventBandIndex=np.argmin(np.abs(energyBands-8000))
#compute the index of the first relavent band
firstRelaventBandIndex=finalRelaventBandIndex-preprocessedSpectra.shape[1]+1
#get the energies of the relavent bands
relaventEnergyBands=energyBands[firstRelaventBandIndex:finalRelaventBandIndex+1]

# %%
#remove the variables no longer needed from memory
del firstRelaventBandIndex
del finalRelaventBandIndex
del energyBands
del gain
del dataframe
del dataFramePickleAddress

# %%
#import pyplot from matplotlib
import matplotlib.pyplot as plt

# %%
#set plot parameters
baseFontSize=18
noOfBinsForHistogram=100
noOfXticks=5

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=3,
                         figsize=(15,5),
                         dpi=200)
#iterate over all elements
for i in range(elementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(atomicAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(elementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("Wt frac.",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(atomicAbundances[:,i]),
                                 np.amax(atomicAbundances[:,i])+np.ptp(atomicAbundances[:,i])/noOfXticks,
                                 np.ptp(atomicAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(atomicAbundances[:,i]),
                                                 np.amax(atomicAbundances[:,i])+np.ptp(atomicAbundances[:,i])/noOfXticks,
                                                 np.ptp(atomicAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure
plt.figure(figsize=(30,15),
           dpi=100)
#and plot all the spectra
for i in range(preprocessedSpectra.shape[0]):
    plt.plot(relaventEnergyBands,
             preprocessedSpectra[i,:],
             lw=5)
#annotate the figure
plt.title("Preprocessed GRS Spectra",
          fontsize=baseFontSize*1.8)
plt.xticks(np.arange(np.amin(relaventEnergyBands),
                     np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                     np.ptp(relaventEnergyBands)/noOfXticks),
           fontsize=baseFontSize*1.2)
plt.yticks(np.arange(np.amin(preprocessedSpectra),
                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                     np.ptp(preprocessedSpectra)/noOfXticks),
           labels=np.round(np.arange(np.amin(preprocessedSpectra),
                                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                                     np.ptp(preprocessedSpectra)/noOfXticks),
                           2),
           fontsize=baseFontSize*1.2)
plt.xlabel("KeV",
           fontsize=baseFontSize*1.5)
plt.ylabel("log(Counts/min) ratioed",
           fontsize=baseFontSize*1.5)
plt.margins(0)

# %%
#import tensorflow
import tensorflow as tf

# %%
#set a global seed value
globalSeed=23

# %%
#load the pre-trained models
#define a funtion to calculate the Pearsons correlation between two sets of values
def pearson_correlation(x,y):
    x_mean=tf.reduce_mean(x)
    y_mean=tf.reduce_mean(y)
    x_diff=x-x_mean
    y_diff=y-y_mean
    covariance=tf.reduce_mean(tf.multiply(x_diff,y_diff))
    x_std=tf.sqrt(tf.reduce_mean(tf.square(x_diff)))
    y_std=tf.sqrt(tf.reduce_mean(tf.square(y_diff)))
    correlation=covariance/(x_std*y_std)
    return correlation

# %%
# define a funtion which creates the CAM (Channel Attention Module)
def createCAM(inputFeatureBlock,reductionRatio):
    #perform max pooling along the channel dimension
    channelMaxPooledFeatures=tf.math.reduce_max(inputFeatureBlock,
                                                axis=1,
                                                keepdims=False)
    
    #perform avg pooling along the channel dimension
    channelAvgPooledFeatures=tf.math.reduce_mean(inputFeatureBlock,
                                                 axis=1,
                                                 keepdims=False)
    
    #create the bottleneck for the MLP
    bottleneckLayer=tf.keras.layers.Dense(channelAvgPooledFeatures.shape[-1]//reductionRatio,
                                          activation='relu')
    
    #create the recontruction layer for the MLP
    outputLayer=tf.keras.layers.Dense(channelAvgPooledFeatures.shape[-1],
                                      activation='relu')
    
    #create a dropout layer for both MLP layers
    bottleNeckDropout=tf.keras.layers.Dropout(0.5,
                                              noise_shape=None,
                                              seed=globalSeed)
    
    OutputDropout=tf.keras.layers.Dropout(0.5,
                                          noise_shape=None,
                                          seed=globalSeed)
    
    #pass the max pooled features through the bottle-neck
    reconstructeedMaxPooledFeatures=outputLayer(bottleneckLayer(channelMaxPooledFeatures))
    
    
    #pass the avg pooled features through the bottle-neck
    reconstructeedAvgPooledFeatures=outputLayer(bottleneckLayer(channelMaxPooledFeatures))
    
    
    #add the two reconstructed features together
    summedFeatures=tf.math.add(reconstructeedMaxPooledFeatures,
                               reconstructeedAvgPooledFeatures)
    
    #apply sigmoid activation to the summed features to get the channel attention map
    channelAttentionMap=tf.keras.activations.sigmoid(summedFeatures)
    
    #return the channel attention map
    return channelAttentionMap

# %%
#define a function to create the Spatial attention module (SAM)
def createSAM(inputFeatureBlock,kernelSize):
    #perform max pooling on the input features
    maxPooledFeatureMap=tf.math.reduce_max(inputFeatureBlock,
                                           axis=-1,
                                           keepdims=False)
    #perform average pooling on the input features
    averagePooledFeatureMap=tf.math.reduce_mean(inputFeatureBlock,
                                                 axis=-1,
                                                 keepdims=False)
    
    #concatenate the feature maps together
    concatenatedFeatureMaps=tf.concat([tf.expand_dims(maxPooledFeatureMap,
                                                      axis=-1),
                                       tf.expand_dims(averagePooledFeatureMap,
                                                      axis=-1)],
                                      axis=-1)
    
    #create the convolutional layer to be applied to the concatenated feature map
    convolutionLayer=tf.keras.layers.Conv1D(filters=1,
                                            kernel_size=kernelSize,
                                            strides=1,
                                            padding='same',
                                            activation='sigmoid')
    #create and add a dropout layer
    spatialDropoutLayer=tf.keras.layers.Dropout(0.5,
                                                noise_shape=None,
                                                seed=globalSeed)
    
    
    #get the spatial attention map
    spatialAttentionMap=convolutionLayer(concatenatedFeatureMaps)
    
    
    #return the channel attention map
    return spatialAttentionMap

# %%
#define a function which creates a CBAM block
def createCBAM(inputLayer,convolutionalKernelSize,noOfConvolutionalFilters,reductionRatio,spatialKernelSize):
    #create a convolutional layer
    convolutionalLayer=tf.keras.layers.Conv1D(filters=noOfConvolutionalFilters,
                                              kernel_size=convolutionalKernelSize,
                                              strides=1,
                                              padding='same')
    #get the feature block from the convolutional layer
    convolutionalFeatures=convolutionalLayer(inputLayer)
    
    #get the channel attention map
    channelAttentionMap=createCAM(convolutionalFeatures,
                                  reductionRatio)
    
    #replicate the channel attention to make it multiplicative with the features
    replicatedChannelAttentionMaps=tf.expand_dims(channelAttentionMap,
                                                  axis=1)
    replicatedChannelAttentionMaps=tf.repeat(replicatedChannelAttentionMaps,
                                             convolutionalFeatures.shape[1],
                                             axis=1)
    
    #compute the channel refined feature by performing element-wise multiplication between the features and the channel attention maps
    channelRefinedFeatures=tf.math.multiply(replicatedChannelAttentionMaps,
                                            convolutionalFeatures)
    
    '''
    #apply batch norm to the refined features
    channelRefinedFeatures=tf.keras.layers.BatchNormalization()(channelRefinedFeatures)
    '''
    
    #get the spatial attention map
    spatialAttentionMap=createSAM(channelRefinedFeatures,
                                  spatialKernelSize)
    
    #replicate the attention map to make it multiplicative with the channel-refined features
    replicatedSpatialAttentionMaps=tf.repeat(spatialAttentionMap,
                                             channelRefinedFeatures.shape[-1],
                                             axis=-1)
    
    #multiply the attention map with the channel refined features
    spatiallyRefinedFeatures=tf.math.multiply(replicatedSpatialAttentionMaps,
                                              channelRefinedFeatures)
    
    '''
    #apply batch norm to the refined features
    spatiallyRefinedFeatures=tf.keras.layers.BatchNormalization()(spatiallyRefinedFeatures)
    '''
    
    
    #add the refined features to the original features
    refinedFeatures=tf.math.add(convolutionalFeatures,
                                spatiallyRefinedFeatures)
    
    #return the refined features (i.e. the output of the CBAM)
    return refinedFeatures

# %%
#compute the number of channels in the pre-processed spectra
noOfChannels=preprocessedSpectra.shape[1]

# %%
#create an input layer
inputLayer=tf.keras.Input(shape=(noOfChannels,
                                 1))

# %%
#create a NN (Neural Network) graph containing just the input layer
nnGraph=inputLayer

# %%
#create a convolutional block
firstConvolutionalLayer=tf.keras.layers.Conv1D(filters=64,
                                               kernel_size=7,
                                               strides=1,
                                               padding='same',
                                               name="1st_Conv_layer")
#add the 1st Conv layer to the graph
nnGraph=firstConvolutionalLayer(nnGraph)

#apply Relu activation
firstReluActivation=tf.keras.layers.Activation('relu',
                                               name="1st_Activation")
#add the 1st activation layer to the graph
nnGraph=firstReluActivation(nnGraph)

#apply batch normalization
firstBatchNormalization=tf.keras.layers.BatchNormalization(name="1st_Batch_Norm")
#add the 1st batch-norm layer to the graph
nnGraph=firstBatchNormalization(nnGraph)

#apply dropout
firstDropoutLayer=tf.keras.layers.Dropout(0.5,
                                          noise_shape=None,
                                          seed=globalSeed,
                                          name="1st_Dropout")
#add the 1st dropout layer to the graph
nnGraph=firstDropoutLayer(nnGraph)

# %%
#create a list containing the number of features to be outputted by each CBAM block
noOfChannelsInEachCBAMBlock=[64,
                             128,
                             256,
                             512]

# %%
#iterate through all the number of channels and add CBAM blocks
for i in range(len(noOfChannelsInEachCBAMBlock)):
    #get the current number of channels 
    currentNumberOfChannels=noOfChannelsInEachCBAMBlock[i]
    #add a CBAM block to the network
    nnGraph=createCBAM(nnGraph,
                       convolutionalKernelSize=3,
                       noOfConvolutionalFilters=currentNumberOfChannels,
                       reductionRatio=6,spatialKernelSize=7)

    #create a flag indicating if the features are to be pooled
    performPooling=False
    try:
        #check if the number of of channels changes in the next block, if so set the pooling flag to true
        if noOfChannelsInEachCBAMBlock[i]!=noOfChannelsInEachCBAMBlock[i+1]:
            performPooling=True
    except:
        performPooling=False
    #check if the flag is true, if it is perform average pooling
    if performPooling:
        nnGraph=tf.keras.layers.AveragePooling1D(pool_size=2)(nnGraph)
    
    #print the shape of the current tensor
    print(f"Shape of the tensor outputted by the {i}th CBAM block #{nnGraph.shape}")
# Out:
# Shape of the tensor outputted by the 0th CBAM block #(None, 210, 64)
# Shape of the tensor outputted by the 1th CBAM block #(None, 105, 128)
# Shape of the tensor outputted by the 2th CBAM block #(None, 52, 256)
# Shape of the tensor outputted by the 3th CBAM block #(None, 52, 512)

# %%
#perform global average pooling
nnGraph=tf.keras.layers.GlobalAveragePooling1D()(nnGraph)

# %%
#print the shape of the average pooled features
print(f"No. of nodes outputted by the Global pooling layer {nnGraph.shape}")
# Out:
# No. of nodes outputted by the Global pooling layer (None, 512)

# %%
#add a fully connected layer to the network for estimating atomic abundances
AtomicAbundanceLayer=tf.keras.layers.Dense(3,
                                           activation='relu',
                                           name="Atomic_Element_Abundance")

# %%
#apply a maximum limit of 1 to the atomic minerals
estimatedAtomicAbundances=tf.clip_by_value(AtomicAbundanceLayer(nnGraph),
                                  clip_value_min=0,
                                  clip_value_max=1)
nnGraph=estimatedAtomicAbundances

# %%
#print the shape of the output layer
print(f"No. of nodes in the output layer {nnGraph.shape}")
# Out:
# No. of nodes in the output layer (None, 3)

# %%
#build the model
jointAbundanceEstimator=tf.keras.Model(inputs=inputLayer,
                                       outputs=[estimatedAtomicAbundances],
                                       name="Atomic_Abundance_estimator")

# %%
#create the loss function for the embedding, Mean Squared Error
lossFunction=tf.keras.losses.MeanSquaredError()
#create the optimizer
optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4)
#set the number of epochs the model is to be trained for
noOfEpochs=450
#set the batch size
batchSize=32

# %%
#compile the model
jointAbundanceEstimator.compile(optimizer=optimizer,
                                loss=lossFunction,
                                metrics=[pearson_correlation],
                                steps_per_execution=45)

# %%
#set the address where the untrained model will be saved
untrainedModelAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Joint_Abundance_Attention_Model.h5"

# %%
#save the untrained model
tf.keras.models.save_model(jointAbundanceEstimator,
                           untrainedModelAddress,
                           overwrite=True)

# %%
#import KFold from sklearn, to be used for KFold validation
from sklearn.model_selection import KFold

# %%
#set no. of folds over which the model is to be validated
noOfFolds=5

# %%
#create a K-Fold splitter
splitter=KFold(n_splits=noOfFolds,
               shuffle=True,
               random_state=globalSeed)

# %%
#check if the GPU is available
if len(tf.config.list_physical_devices('GPU'))==1:
    print("GPU available")
else:
    print("GPU unavailable")
# Out:
# GPU available

# %%
#create a list to hold model training history
modelTrainingHistories=[]
#create a list to store the trained models
trainedModels=[]

# %%
#iterate through the folds
for i,(trainingIndices,testingIndices) in enumerate(splitter.split(atomicAbundances[:,0])):
    #print the current fold number
    print(f"Starting processing fold {i+1}")
    
    #build the model
    jointAbundanceEstimator=tf.keras.Model(inputs=inputLayer,
                                       outputs=[estimatedAtomicAbundances],
                                       name="Multitask_Abundance_estimator")
    
    #compile the model
    jointAbundanceEstimator.compile(optimizer=optimizer,
                                loss=lossFunction,
                                metrics=[pearson_correlation],
                                steps_per_execution=45)
    
    #fit the model to the current fold's data
    currentModelTrainingHistory=jointAbundanceEstimator.fit(x=preprocessedSpectra[trainingIndices,:],
                                                            y=atomicAbundances[trainingIndices,:],
                                                            batch_size=batchSize,
                                                            epochs=noOfEpochs,
                                                            validation_data=(preprocessedSpectra[testingIndices,:],
                                                                             atomicAbundances[testingIndices,:]),
                                                            validation_freq=1)
                                                            
    
    #save the training history of the current model
    modelTrainingHistories.append(currentModelTrainingHistory)
    
    
    #set the address where the trained model from the current 
    currentFoldTrainedModelAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Joint_Abundance_Attention_Model"+str(i+1)+".h5"
    
    #save the trained model
    trainedModels.append(jointAbundanceEstimator)
    
    '''
    #remove the trained model from memory
    jointAbundanceEstimator=None
    del jointAbundanceEstimator
    '''
    
    break
# Out:
# Starting processing fold 1
# Epoch 1/450
# 45/45 [==============================] - 11s 243ms/step - loss: 0.0260 - pearson_correlation: 0.5240 - val_loss: 0.0421 - val_pearson_correlation: 0.3100
# Epoch 2/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0131 - pearson_correlation: 0.7744 - val_loss: 0.0517 - val_pearson_correlation: 0.4801
# Epoch 3/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0127 - pearson_correlation: 0.7861 - val_loss: 0.0514 - val_pearson_correlation: 0.4433
# Epoch 4/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0114 - pearson_correlation: 0.8366 - val_loss: 0.0442 - val_pearson_correlation: 0.5205
# Epoch 5/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0100 - pearson_correlation: 0.8401 - val_loss: 0.0425 - val_pearson_correlation: 0.6167
# Epoch 6/450
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0093 - pearson_correlation: 0.8546 - val_loss: 0.0523 - val_pearson_correlation: 0.6894
# Epoch 7/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0084 - pearson_correlation: 0.8642 - val_loss: 0.0410 - val_pearson_correlation: 0.6869
# Epoch 8/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0076 - pearson_correlation: 0.8669 - val_loss: 0.0423 - val_pearson_correlation: 0.7842
# Epoch 9/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0075 - pearson_correlation: 0.8859 - val_loss: 0.0307 - val_pearson_correlation: 0.7993
# Epoch 10/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0075 - pearson_correlation: 0.8815 - val_loss: 0.0308 - val_pearson_correlation: 0.8245
# Epoch 11/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0072 - pearson_correlation: 0.8898 - val_loss: 0.0281 - val_pearson_correlation: 0.8704
# Epoch 12/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0073 - pearson_correlation: 0.8822 - val_loss: 0.0184 - val_pearson_correlation: 0.8870
# Epoch 13/450
# 45/45 [==============================] - 2s 44ms/step - loss: 0.0067 - pearson_correlation: 0.9029 - val_loss: 0.0145 - val_pearson_correlation: 0.8916
# Epoch 14/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0070 - pearson_correlation: 0.8931 - val_loss: 0.0161 - val_pearson_correlation: 0.9057
# Epoch 15/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0070 - pearson_correlation: 0.8905 - val_loss: 0.0132 - val_pearson_correlation: 0.9137
# Epoch 16/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0059 - pearson_correlation: 0.9148 - val_loss: 0.0068 - val_pearson_correlation: 0.9112
# Epoch 17/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0072 - pearson_correlation: 0.8988 - val_loss: 0.0268 - val_pearson_correlation: 0.9114
# Epoch 18/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0063 - pearson_correlation: 0.9126 - val_loss: 0.0071 - val_pearson_correlation: 0.9197
# Epoch 19/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0058 - pearson_correlation: 0.9153 - val_loss: 0.0046 - val_pearson_correlation: 0.9130
# Epoch 20/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0058 - pearson_correlation: 0.9079 - val_loss: 0.0042 - val_pearson_correlation: 0.9203
# Epoch 21/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0061 - pearson_correlation: 0.9085 - val_loss: 0.0195 - val_pearson_correlation: 0.8992
# Epoch 22/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0063 - pearson_correlation: 0.9009 - val_loss: 0.0050 - val_pearson_correlation: 0.9244
# Epoch 23/450
# 45/45 [==============================] - 2s 33ms/step - loss: 0.0060 - pearson_correlation: 0.9188 - val_loss: 0.0042 - val_pearson_correlation: 0.9197
# Epoch 24/450
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0060 - pearson_correlation: 0.9191 - val_loss: 0.0112 - val_pearson_correlation: 0.9208
# Epoch 25/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0054 - pearson_correlation: 0.9217 - val_loss: 0.0060 - val_pearson_correlation: 0.9125
# Epoch 26/450
# 45/45 [==============================] - 2s 42ms/step - loss: 0.0055 - pearson_correlation: 0.9247 - val_loss: 0.0064 - val_pearson_correlation: 0.9260
# Epoch 27/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0056 - pearson_correlation: 0.9195 - val_loss: 0.0050 - val_pearson_correlation: 0.9246
# Epoch 28/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0051 - pearson_correlation: 0.9162 - val_loss: 0.0045 - val_pearson_correlation: 0.9256
# Epoch 29/450
# 45/45 [==============================] - 2s 41ms/step - loss: 0.0050 - pearson_correlation: 0.9298 - val_loss: 0.0166 - val_pearson_correlation: 0.9100
# Epoch 30/450
# 45/45 [==============================] - 5s 110ms/step - loss: 0.0050 - pearson_correlation: 0.9298 - val_loss: 0.0083 - val_pearson_correlation: 0.9214
# Epoch 31/450
# 45/45 [==============================] - 8s 172ms/step - loss: 0.0050 - pearson_correlation: 0.9176 - val_loss: 0.0041 - val_pearson_correlation: 0.9285
# Epoch 32/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0051 - pearson_correlation: 0.9166 - val_loss: 0.0066 - val_pearson_correlation: 0.9339
# Epoch 33/450
# 45/45 [==============================] - 8s 187ms/step - loss: 0.0049 - pearson_correlation: 0.9334 - val_loss: 0.0035 - val_pearson_correlation: 0.9273
# Epoch 34/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0041 - pearson_correlation: 0.9360 - val_loss: 0.0076 - val_pearson_correlation: 0.9311
# Epoch 35/450
# 45/45 [==============================] - 6s 143ms/step - loss: 0.0045 - pearson_correlation: 0.9346 - val_loss: 0.0031 - val_pearson_correlation: 0.9341
# Epoch 36/450
# 45/45 [==============================] - 7s 166ms/step - loss: 0.0038 - pearson_correlation: 0.9395 - val_loss: 0.0029 - val_pearson_correlation: 0.9338
# Epoch 37/450
# 45/45 [==============================] - 7s 151ms/step - loss: 0.0040 - pearson_correlation: 0.9343 - val_loss: 0.0029 - val_pearson_correlation: 0.9378
# Epoch 38/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0033 - pearson_correlation: 0.9444 - val_loss: 0.0025 - val_pearson_correlation: 0.9382
# Epoch 39/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0036 - pearson_correlation: 0.9434 - val_loss: 0.0047 - val_pearson_correlation: 0.9372
# Epoch 40/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0035 - pearson_correlation: 0.9370 - val_loss: 0.0152 - val_pearson_correlation: 0.9395
# Epoch 41/450
# 45/45 [==============================] - 8s 172ms/step - loss: 0.0031 - pearson_correlation: 0.9461 - val_loss: 0.0099 - val_pearson_correlation: 0.9408
# Epoch 42/450
# 45/45 [==============================] - 7s 153ms/step - loss: 0.0040 - pearson_correlation: 0.9437 - val_loss: 0.0054 - val_pearson_correlation: 0.9372
# Epoch 43/450
# 45/45 [==============================] - 7s 147ms/step - loss: 0.0034 - pearson_correlation: 0.9476 - val_loss: 0.0053 - val_pearson_correlation: 0.9417
# Epoch 44/450
# 45/45 [==============================] - 8s 177ms/step - loss: 0.0033 - pearson_correlation: 0.9462 - val_loss: 0.0044 - val_pearson_correlation: 0.9435
# Epoch 45/450
# 45/45 [==============================] - 8s 173ms/step - loss: 0.0032 - pearson_correlation: 0.9418 - val_loss: 0.0028 - val_pearson_correlation: 0.9463
# Epoch 46/450
# 45/45 [==============================] - 8s 186ms/step - loss: 0.0029 - pearson_correlation: 0.9550 - val_loss: 0.0023 - val_pearson_correlation: 0.9466
# Epoch 47/450
# 45/45 [==============================] - 8s 170ms/step - loss: 0.0028 - pearson_correlation: 0.9550 - val_loss: 0.0024 - val_pearson_correlation: 0.9478
# Epoch 48/450
# 45/45 [==============================] - 7s 145ms/step - loss: 0.0030 - pearson_correlation: 0.9482 - val_loss: 0.0066 - val_pearson_correlation: 0.9457
# Epoch 49/450
# 45/45 [==============================] - 8s 169ms/step - loss: 0.0027 - pearson_correlation: 0.9568 - val_loss: 0.0031 - val_pearson_correlation: 0.9487
# Epoch 50/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0027 - pearson_correlation: 0.9587 - val_loss: 0.0021 - val_pearson_correlation: 0.9480
# Epoch 51/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0027 - pearson_correlation: 0.9556 - val_loss: 0.0025 - val_pearson_correlation: 0.9473
# Epoch 52/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0030 - pearson_correlation: 0.9536 - val_loss: 0.0031 - val_pearson_correlation: 0.9473
# Epoch 53/450
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0026 - pearson_correlation: 0.9515 - val_loss: 0.0027 - val_pearson_correlation: 0.9494
# Epoch 54/450
# 45/45 [==============================] - 6s 133ms/step - loss: 0.0025 - pearson_correlation: 0.9559 - val_loss: 0.0030 - val_pearson_correlation: 0.9488
# Epoch 55/450
# 45/45 [==============================] - 7s 166ms/step - loss: 0.0025 - pearson_correlation: 0.9586 - val_loss: 0.0024 - val_pearson_correlation: 0.9465
# Epoch 56/450
# 45/45 [==============================] - 6s 142ms/step - loss: 0.0026 - pearson_correlation: 0.9584 - val_loss: 0.0026 - val_pearson_correlation: 0.9465
# Epoch 57/450
# 45/45 [==============================] - 8s 182ms/step - loss: 0.0029 - pearson_correlation: 0.9557 - val_loss: 0.0022 - val_pearson_correlation: 0.9504
# Epoch 58/450
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0024 - pearson_correlation: 0.9579 - val_loss: 0.0020 - val_pearson_correlation: 0.9513
# Epoch 59/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0023 - pearson_correlation: 0.9577 - val_loss: 0.0021 - val_pearson_correlation: 0.9509
# Epoch 60/450
# 45/45 [==============================] - 7s 158ms/step - loss: 0.0024 - pearson_correlation: 0.9596 - val_loss: 0.0031 - val_pearson_correlation: 0.9509
# Epoch 61/450
# 45/45 [==============================] - 7s 163ms/step - loss: 0.0024 - pearson_correlation: 0.9602 - val_loss: 0.0020 - val_pearson_correlation: 0.9543
# Epoch 62/450
# 45/45 [==============================] - 7s 145ms/step - loss: 0.0026 - pearson_correlation: 0.9550 - val_loss: 0.0025 - val_pearson_correlation: 0.9472
# Epoch 63/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0026 - pearson_correlation: 0.9552 - val_loss: 0.0039 - val_pearson_correlation: 0.9541
# Epoch 64/450
# 45/45 [==============================] - 8s 173ms/step - loss: 0.0022 - pearson_correlation: 0.9619 - val_loss: 0.0022 - val_pearson_correlation: 0.9529
# Epoch 65/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0024 - pearson_correlation: 0.9604 - val_loss: 0.0023 - val_pearson_correlation: 0.9471
# Epoch 66/450
# 45/45 [==============================] - 7s 153ms/step - loss: 0.0021 - pearson_correlation: 0.9617 - val_loss: 0.0017 - val_pearson_correlation: 0.9571
# Epoch 67/450
# 45/45 [==============================] - 7s 147ms/step - loss: 0.0022 - pearson_correlation: 0.9629 - val_loss: 0.0024 - val_pearson_correlation: 0.9537
# Epoch 68/450
# 45/45 [==============================] - 8s 174ms/step - loss: 0.0023 - pearson_correlation: 0.9607 - val_loss: 0.0017 - val_pearson_correlation: 0.9574
# Epoch 69/450
# 45/45 [==============================] - 7s 166ms/step - loss: 0.0021 - pearson_correlation: 0.9665 - val_loss: 0.0019 - val_pearson_correlation: 0.9546
# Epoch 70/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0021 - pearson_correlation: 0.9565 - val_loss: 0.0019 - val_pearson_correlation: 0.9527
# Epoch 71/450
# 45/45 [==============================] - 13s 279ms/step - loss: 0.0020 - pearson_correlation: 0.9655 - val_loss: 0.0019 - val_pearson_correlation: 0.9540
# Epoch 72/450
# 45/45 [==============================] - 7s 164ms/step - loss: 0.0019 - pearson_correlation: 0.9623 - val_loss: 0.0020 - val_pearson_correlation: 0.9591
# Epoch 73/450
# 45/45 [==============================] - 7s 166ms/step - loss: 0.0020 - pearson_correlation: 0.9649 - val_loss: 0.0019 - val_pearson_correlation: 0.9550
# Epoch 74/450
# 45/45 [==============================] - 7s 163ms/step - loss: 0.0020 - pearson_correlation: 0.9653 - val_loss: 0.0022 - val_pearson_correlation: 0.9578
# Epoch 75/450
# 45/45 [==============================] - 6s 132ms/step - loss: 0.0020 - pearson_correlation: 0.9674 - val_loss: 0.0018 - val_pearson_correlation: 0.9591
# Epoch 76/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0020 - pearson_correlation: 0.9660 - val_loss: 0.0020 - val_pearson_correlation: 0.9545
# Epoch 77/450
# 45/45 [==============================] - 8s 182ms/step - loss: 0.0019 - pearson_correlation: 0.9667 - val_loss: 0.0017 - val_pearson_correlation: 0.9590
# Epoch 78/450
# 45/45 [==============================] - 9s 205ms/step - loss: 0.0019 - pearson_correlation: 0.9694 - val_loss: 0.0022 - val_pearson_correlation: 0.9547
# Epoch 79/450
# 45/45 [==============================] - 8s 172ms/step - loss: 0.0020 - pearson_correlation: 0.9687 - val_loss: 0.0021 - val_pearson_correlation: 0.9600
# Epoch 80/450
# 45/45 [==============================] - 8s 171ms/step - loss: 0.0020 - pearson_correlation: 0.9661 - val_loss: 0.0020 - val_pearson_correlation: 0.9584
# Epoch 81/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0019 - pearson_correlation: 0.9696 - val_loss: 0.0020 - val_pearson_correlation: 0.9561
# Epoch 82/450
# 45/45 [==============================] - 7s 156ms/step - loss: 0.0019 - pearson_correlation: 0.9657 - val_loss: 0.0021 - val_pearson_correlation: 0.9589
# Epoch 83/450
# 45/45 [==============================] - 8s 173ms/step - loss: 0.0020 - pearson_correlation: 0.9644 - val_loss: 0.0020 - val_pearson_correlation: 0.9585
# Epoch 84/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0020 - pearson_correlation: 0.9657 - val_loss: 0.0016 - val_pearson_correlation: 0.9609
# Epoch 85/450
# 45/45 [==============================] - 10s 227ms/step - loss: 0.0018 - pearson_correlation: 0.9698 - val_loss: 0.0017 - val_pearson_correlation: 0.9629
# Epoch 86/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0019 - pearson_correlation: 0.9629 - val_loss: 0.0017 - val_pearson_correlation: 0.9572
# Epoch 87/450
# 45/45 [==============================] - 7s 148ms/step - loss: 0.0018 - pearson_correlation: 0.9685 - val_loss: 0.0027 - val_pearson_correlation: 0.9563
# Epoch 88/450
# 45/45 [==============================] - 7s 166ms/step - loss: 0.0020 - pearson_correlation: 0.9667 - val_loss: 0.0021 - val_pearson_correlation: 0.9586
# Epoch 89/450
# 45/45 [==============================] - 7s 162ms/step - loss: 0.0018 - pearson_correlation: 0.9690 - val_loss: 0.0017 - val_pearson_correlation: 0.9591
# Epoch 90/450
# 45/45 [==============================] - 8s 175ms/step - loss: 0.0019 - pearson_correlation: 0.9670 - val_loss: 0.0018 - val_pearson_correlation: 0.9586
# Epoch 91/450
# 45/45 [==============================] - 8s 177ms/step - loss: 0.0019 - pearson_correlation: 0.9691 - val_loss: 0.0017 - val_pearson_correlation: 0.9634
# Epoch 92/450
# 45/45 [==============================] - 9s 207ms/step - loss: 0.0018 - pearson_correlation: 0.9711 - val_loss: 0.0019 - val_pearson_correlation: 0.9580
# Epoch 93/450
# 45/45 [==============================] - 7s 157ms/step - loss: 0.0017 - pearson_correlation: 0.9661 - val_loss: 0.0017 - val_pearson_correlation: 0.9632
# Epoch 94/450
# 45/45 [==============================] - 8s 168ms/step - loss: 0.0017 - pearson_correlation: 0.9679 - val_loss: 0.0024 - val_pearson_correlation: 0.9619
# Epoch 95/450
# 45/45 [==============================] - 7s 160ms/step - loss: 0.0019 - pearson_correlation: 0.9690 - val_loss: 0.0029 - val_pearson_correlation: 0.9624
# Epoch 96/450
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0020 - pearson_correlation: 0.9677 - val_loss: 0.0017 - val_pearson_correlation: 0.9570
# Epoch 97/450
# 45/45 [==============================] - 8s 175ms/step - loss: 0.0017 - pearson_correlation: 0.9675 - val_loss: 0.0017 - val_pearson_correlation: 0.9628
# Epoch 98/450
# 45/45 [==============================] - 8s 180ms/step - loss: 0.0018 - pearson_correlation: 0.9699 - val_loss: 0.0017 - val_pearson_correlation: 0.9611
# Epoch 99/450
# 45/45 [==============================] - 10s 231ms/step - loss: 0.0017 - pearson_correlation: 0.9709 - val_loss: 0.0020 - val_pearson_correlation: 0.9590
# Epoch 100/450
# 45/45 [==============================] - 7s 147ms/step - loss: 0.0017 - pearson_correlation: 0.9686 - val_loss: 0.0017 - val_pearson_correlation: 0.9621
# Epoch 101/450
# 45/45 [==============================] - 7s 157ms/step - loss: 0.0017 - pearson_correlation: 0.9682 - val_loss: 0.0016 - val_pearson_correlation: 0.9645
# Epoch 102/450
# 45/45 [==============================] - 7s 156ms/step - loss: 0.0017 - pearson_correlation: 0.9674 - val_loss: 0.0016 - val_pearson_correlation: 0.9582
# Epoch 103/450
# 45/45 [==============================] - 7s 145ms/step - loss: 0.0018 - pearson_correlation: 0.9697 - val_loss: 0.0017 - val_pearson_correlation: 0.9623
# Epoch 104/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0016 - pearson_correlation: 0.9730 - val_loss: 0.0015 - val_pearson_correlation: 0.9634
# Epoch 105/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9680 - val_loss: 0.0023 - val_pearson_correlation: 0.9637
# Epoch 106/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0017 - pearson_correlation: 0.9707 - val_loss: 0.0017 - val_pearson_correlation: 0.9606
# Epoch 107/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9732 - val_loss: 0.0017 - val_pearson_correlation: 0.9599
# Epoch 108/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0016 - pearson_correlation: 0.9699 - val_loss: 0.0020 - val_pearson_correlation: 0.9610
# Epoch 109/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0016 - pearson_correlation: 0.9733 - val_loss: 0.0016 - val_pearson_correlation: 0.9620
# Epoch 110/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0016 - pearson_correlation: 0.9716 - val_loss: 0.0016 - val_pearson_correlation: 0.9608
# Epoch 111/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0016 - pearson_correlation: 0.9743 - val_loss: 0.0018 - val_pearson_correlation: 0.9641
# Epoch 112/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0016 - pearson_correlation: 0.9648 - val_loss: 0.0019 - val_pearson_correlation: 0.9629
# Epoch 113/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0019 - pearson_correlation: 0.9708 - val_loss: 0.0025 - val_pearson_correlation: 0.9601
# Epoch 114/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0018 - pearson_correlation: 0.9702 - val_loss: 0.0015 - val_pearson_correlation: 0.9647
# Epoch 115/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0017 - pearson_correlation: 0.9702 - val_loss: 0.0020 - val_pearson_correlation: 0.9617
# Epoch 116/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0016 - pearson_correlation: 0.9702 - val_loss: 0.0021 - val_pearson_correlation: 0.9630
# Epoch 117/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9727 - val_loss: 0.0015 - val_pearson_correlation: 0.9648
# Epoch 118/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9700 - val_loss: 0.0016 - val_pearson_correlation: 0.9662
# Epoch 119/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0018 - pearson_correlation: 0.9737 - val_loss: 0.0016 - val_pearson_correlation: 0.9613
# Epoch 120/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0016 - pearson_correlation: 0.9723 - val_loss: 0.0014 - val_pearson_correlation: 0.9642
# Epoch 121/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0015 - pearson_correlation: 0.9711 - val_loss: 0.0015 - val_pearson_correlation: 0.9657
# Epoch 122/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9748 - val_loss: 0.0025 - val_pearson_correlation: 0.9614
# Epoch 123/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9751 - val_loss: 0.0015 - val_pearson_correlation: 0.9617
# Epoch 124/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0015 - pearson_correlation: 0.9722 - val_loss: 0.0016 - val_pearson_correlation: 0.9593
# Epoch 125/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0016 - pearson_correlation: 0.9731 - val_loss: 0.0015 - val_pearson_correlation: 0.9645
# Epoch 126/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9723 - val_loss: 0.0017 - val_pearson_correlation: 0.9647
# Epoch 127/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9746 - val_loss: 0.0020 - val_pearson_correlation: 0.9618
# Epoch 128/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9692 - val_loss: 0.0019 - val_pearson_correlation: 0.9657
# Epoch 129/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0016 - pearson_correlation: 0.9684 - val_loss: 0.0017 - val_pearson_correlation: 0.9651
# Epoch 130/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9744 - val_loss: 0.0014 - val_pearson_correlation: 0.9677
# Epoch 131/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9714 - val_loss: 0.0021 - val_pearson_correlation: 0.9631
# Epoch 132/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9748 - val_loss: 0.0015 - val_pearson_correlation: 0.9654
# Epoch 133/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9734 - val_loss: 0.0015 - val_pearson_correlation: 0.9645
# Epoch 134/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9750 - val_loss: 0.0016 - val_pearson_correlation: 0.9608
# Epoch 135/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9728 - val_loss: 0.0014 - val_pearson_correlation: 0.9654
# Epoch 136/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9732 - val_loss: 0.0031 - val_pearson_correlation: 0.9608
# Epoch 137/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0018 - pearson_correlation: 0.9737 - val_loss: 0.0015 - val_pearson_correlation: 0.9666
# Epoch 138/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9726 - val_loss: 0.0015 - val_pearson_correlation: 0.9654
# Epoch 139/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9722 - val_loss: 0.0016 - val_pearson_correlation: 0.9641
# Epoch 140/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9710 - val_loss: 0.0014 - val_pearson_correlation: 0.9662
# Epoch 141/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0014 - pearson_correlation: 0.9742 - val_loss: 0.0015 - val_pearson_correlation: 0.9661
# Epoch 142/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9722 - val_loss: 0.0013 - val_pearson_correlation: 0.9666
# Epoch 143/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9757 - val_loss: 0.0016 - val_pearson_correlation: 0.9665
# Epoch 144/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9753 - val_loss: 0.0013 - val_pearson_correlation: 0.9676
# Epoch 145/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9738 - val_loss: 0.0014 - val_pearson_correlation: 0.9677
# Epoch 146/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9759 - val_loss: 0.0014 - val_pearson_correlation: 0.9675
# Epoch 147/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9752 - val_loss: 0.0014 - val_pearson_correlation: 0.9685
# Epoch 148/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9754 - val_loss: 0.0014 - val_pearson_correlation: 0.9665
# Epoch 149/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9737 - val_loss: 0.0014 - val_pearson_correlation: 0.9689
# Epoch 150/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9741 - val_loss: 0.0020 - val_pearson_correlation: 0.9659
# Epoch 151/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0015 - pearson_correlation: 0.9772 - val_loss: 0.0017 - val_pearson_correlation: 0.9641
# Epoch 152/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0016 - pearson_correlation: 0.9738 - val_loss: 0.0014 - val_pearson_correlation: 0.9644
# Epoch 153/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9750 - val_loss: 0.0013 - val_pearson_correlation: 0.9659
# Epoch 154/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9758 - val_loss: 0.0015 - val_pearson_correlation: 0.9651
# Epoch 155/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9744 - val_loss: 0.0015 - val_pearson_correlation: 0.9675
# Epoch 156/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9752 - val_loss: 0.0015 - val_pearson_correlation: 0.9649
# Epoch 157/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9743 - val_loss: 0.0015 - val_pearson_correlation: 0.9673
# Epoch 158/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9746 - val_loss: 0.0014 - val_pearson_correlation: 0.9650
# Epoch 159/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9767 - val_loss: 0.0018 - val_pearson_correlation: 0.9521
# Epoch 160/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9741 - val_loss: 0.0016 - val_pearson_correlation: 0.9673
# Epoch 161/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9753 - val_loss: 0.0016 - val_pearson_correlation: 0.9668
# Epoch 162/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9729 - val_loss: 0.0013 - val_pearson_correlation: 0.9693
# Epoch 163/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0014 - pearson_correlation: 0.9748 - val_loss: 0.0014 - val_pearson_correlation: 0.9653
# Epoch 164/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9734 - val_loss: 0.0014 - val_pearson_correlation: 0.9644
# Epoch 165/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0015 - pearson_correlation: 0.9755 - val_loss: 0.0019 - val_pearson_correlation: 0.9659
# Epoch 166/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0014 - pearson_correlation: 0.9729 - val_loss: 0.0015 - val_pearson_correlation: 0.9631
# Epoch 167/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9739 - val_loss: 0.0016 - val_pearson_correlation: 0.9675
# Epoch 168/450
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0013 - pearson_correlation: 0.9767 - val_loss: 0.0016 - val_pearson_correlation: 0.9683
# Epoch 169/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0014 - pearson_correlation: 0.9764 - val_loss: 0.0017 - val_pearson_correlation: 0.9660
# Epoch 170/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9753 - val_loss: 0.0015 - val_pearson_correlation: 0.9661
# Epoch 171/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0014 - pearson_correlation: 0.9760 - val_loss: 0.0019 - val_pearson_correlation: 0.9686
# Epoch 172/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9736 - val_loss: 0.0014 - val_pearson_correlation: 0.9662
# Epoch 173/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9771 - val_loss: 0.0014 - val_pearson_correlation: 0.9657
# Epoch 174/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9777 - val_loss: 0.0014 - val_pearson_correlation: 0.9657
# Epoch 175/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9767 - val_loss: 0.0014 - val_pearson_correlation: 0.9661
# Epoch 176/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0013 - pearson_correlation: 0.9774 - val_loss: 0.0018 - val_pearson_correlation: 0.9578
# Epoch 177/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9762 - val_loss: 0.0014 - val_pearson_correlation: 0.9649
# Epoch 178/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9752 - val_loss: 0.0013 - val_pearson_correlation: 0.9669
# Epoch 179/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9740 - val_loss: 0.0014 - val_pearson_correlation: 0.9671
# Epoch 180/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9775 - val_loss: 0.0014 - val_pearson_correlation: 0.9642
# Epoch 181/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9768 - val_loss: 0.0013 - val_pearson_correlation: 0.9662
# Epoch 182/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9774 - val_loss: 0.0014 - val_pearson_correlation: 0.9677
# Epoch 183/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9796 - val_loss: 0.0012 - val_pearson_correlation: 0.9694
# Epoch 184/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0013 - pearson_correlation: 0.9765 - val_loss: 0.0015 - val_pearson_correlation: 0.9690
# Epoch 185/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9760 - val_loss: 0.0012 - val_pearson_correlation: 0.9675
# Epoch 186/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9761 - val_loss: 0.0012 - val_pearson_correlation: 0.9677
# Epoch 187/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0013 - pearson_correlation: 0.9777 - val_loss: 0.0016 - val_pearson_correlation: 0.9679
# Epoch 188/450
# 45/45 [==============================] - 2s 42ms/step - loss: 0.0013 - pearson_correlation: 0.9757 - val_loss: 0.0014 - val_pearson_correlation: 0.9684
# Epoch 189/450
# 45/45 [==============================] - 2s 42ms/step - loss: 0.0013 - pearson_correlation: 0.9765 - val_loss: 0.0014 - val_pearson_correlation: 0.9691
# Epoch 190/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9761 - val_loss: 0.0013 - val_pearson_correlation: 0.9687
# Epoch 191/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9776 - val_loss: 0.0014 - val_pearson_correlation: 0.9658
# Epoch 192/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9763 - val_loss: 0.0015 - val_pearson_correlation: 0.9688
# Epoch 193/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9782 - val_loss: 0.0014 - val_pearson_correlation: 0.9665
# Epoch 194/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9784 - val_loss: 0.0013 - val_pearson_correlation: 0.9682
# Epoch 195/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9780 - val_loss: 0.0014 - val_pearson_correlation: 0.9656
# Epoch 196/450
# 45/45 [==============================] - 2s 41ms/step - loss: 0.0014 - pearson_correlation: 0.9777 - val_loss: 0.0013 - val_pearson_correlation: 0.9661
# Epoch 197/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0013 - pearson_correlation: 0.9754 - val_loss: 0.0016 - val_pearson_correlation: 0.9670
# Epoch 198/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9777 - val_loss: 0.0014 - val_pearson_correlation: 0.9668
# Epoch 199/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9775 - val_loss: 0.0019 - val_pearson_correlation: 0.9655
# Epoch 200/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9776 - val_loss: 0.0012 - val_pearson_correlation: 0.9690
# Epoch 201/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9748 - val_loss: 0.0013 - val_pearson_correlation: 0.9675
# Epoch 202/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9780 - val_loss: 0.0013 - val_pearson_correlation: 0.9688
# Epoch 203/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9765 - val_loss: 0.0014 - val_pearson_correlation: 0.9671
# Epoch 204/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0012 - pearson_correlation: 0.9806 - val_loss: 0.0014 - val_pearson_correlation: 0.9678
# Epoch 205/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9759 - val_loss: 0.0013 - val_pearson_correlation: 0.9663
# Epoch 206/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9771 - val_loss: 0.0012 - val_pearson_correlation: 0.9698
# Epoch 207/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9765 - val_loss: 0.0012 - val_pearson_correlation: 0.9682
# Epoch 208/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9772 - val_loss: 0.0013 - val_pearson_correlation: 0.9680
# Epoch 209/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9782 - val_loss: 0.0014 - val_pearson_correlation: 0.9661
# Epoch 210/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9777 - val_loss: 0.0013 - val_pearson_correlation: 0.9651
# Epoch 211/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9770 - val_loss: 0.0014 - val_pearson_correlation: 0.9676
# Epoch 212/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9782 - val_loss: 0.0013 - val_pearson_correlation: 0.9685
# Epoch 213/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9777 - val_loss: 0.0015 - val_pearson_correlation: 0.9664
# Epoch 214/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9769 - val_loss: 0.0013 - val_pearson_correlation: 0.9692
# Epoch 215/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9769 - val_loss: 0.0012 - val_pearson_correlation: 0.9694
# Epoch 216/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9743 - val_loss: 0.0014 - val_pearson_correlation: 0.9688
# Epoch 217/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0013 - pearson_correlation: 0.9760 - val_loss: 0.0012 - val_pearson_correlation: 0.9674
# Epoch 218/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0012 - pearson_correlation: 0.9772 - val_loss: 0.0015 - val_pearson_correlation: 0.9651
# Epoch 219/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9744 - val_loss: 0.0012 - val_pearson_correlation: 0.9706
# Epoch 220/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9756 - val_loss: 0.0013 - val_pearson_correlation: 0.9655
# Epoch 221/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9779 - val_loss: 0.0012 - val_pearson_correlation: 0.9685
# Epoch 222/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9778 - val_loss: 0.0014 - val_pearson_correlation: 0.9622
# Epoch 223/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9764 - val_loss: 0.0014 - val_pearson_correlation: 0.9693
# Epoch 224/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9783 - val_loss: 0.0015 - val_pearson_correlation: 0.9661
# Epoch 225/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9762 - val_loss: 0.0013 - val_pearson_correlation: 0.9690
# Epoch 226/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9772 - val_loss: 0.0017 - val_pearson_correlation: 0.9675
# Epoch 227/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9773 - val_loss: 0.0013 - val_pearson_correlation: 0.9671
# Epoch 228/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0014 - pearson_correlation: 0.9784 - val_loss: 0.0012 - val_pearson_correlation: 0.9699
# Epoch 229/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9765 - val_loss: 0.0013 - val_pearson_correlation: 0.9657
# Epoch 230/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9780 - val_loss: 0.0017 - val_pearson_correlation: 0.9692
# Epoch 231/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0015 - pearson_correlation: 0.9770 - val_loss: 0.0016 - val_pearson_correlation: 0.9651
# Epoch 232/450
# 45/45 [==============================] - 2s 39ms/step - loss: 0.0012 - pearson_correlation: 0.9757 - val_loss: 0.0013 - val_pearson_correlation: 0.9688
# Epoch 233/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0012 - pearson_correlation: 0.9799 - val_loss: 0.0013 - val_pearson_correlation: 0.9669
# Epoch 234/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0012 - pearson_correlation: 0.9798 - val_loss: 0.0012 - val_pearson_correlation: 0.9703
# Epoch 235/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9767 - val_loss: 0.0015 - val_pearson_correlation: 0.9665
# Epoch 236/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9746 - val_loss: 0.0013 - val_pearson_correlation: 0.9685
# Epoch 237/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9771 - val_loss: 0.0012 - val_pearson_correlation: 0.9697
# Epoch 238/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0012 - pearson_correlation: 0.9744 - val_loss: 0.0013 - val_pearson_correlation: 0.9716
# Epoch 239/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9797 - val_loss: 0.0016 - val_pearson_correlation: 0.9684
# Epoch 240/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9777 - val_loss: 0.0013 - val_pearson_correlation: 0.9668
# Epoch 241/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9762 - val_loss: 0.0014 - val_pearson_correlation: 0.9694
# Epoch 242/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9798 - val_loss: 0.0018 - val_pearson_correlation: 0.9687
# Epoch 243/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9777 - val_loss: 0.0013 - val_pearson_correlation: 0.9612
# Epoch 244/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9798 - val_loss: 0.0016 - val_pearson_correlation: 0.9675
# Epoch 245/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9772 - val_loss: 0.0014 - val_pearson_correlation: 0.9676
# Epoch 246/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9749 - val_loss: 0.0012 - val_pearson_correlation: 0.9681
# Epoch 247/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9746 - val_loss: 0.0014 - val_pearson_correlation: 0.9700
# Epoch 248/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9791 - val_loss: 0.0015 - val_pearson_correlation: 0.9654
# Epoch 249/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9776 - val_loss: 0.0015 - val_pearson_correlation: 0.9691
# Epoch 250/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9782 - val_loss: 0.0015 - val_pearson_correlation: 0.9705
# Epoch 251/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9786 - val_loss: 0.0013 - val_pearson_correlation: 0.9688
# Epoch 252/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9792 - val_loss: 0.0018 - val_pearson_correlation: 0.9676
# Epoch 253/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0014 - pearson_correlation: 0.9750 - val_loss: 0.0013 - val_pearson_correlation: 0.9696
# Epoch 254/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9793 - val_loss: 0.0013 - val_pearson_correlation: 0.9664
# Epoch 255/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0014 - pearson_correlation: 0.9755 - val_loss: 0.0015 - val_pearson_correlation: 0.9685
# Epoch 256/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9762 - val_loss: 0.0013 - val_pearson_correlation: 0.9691
# Epoch 257/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9773 - val_loss: 0.0015 - val_pearson_correlation: 0.9641
# Epoch 258/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9793 - val_loss: 0.0019 - val_pearson_correlation: 0.9665
# Epoch 259/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9788 - val_loss: 0.0012 - val_pearson_correlation: 0.9677
# Epoch 260/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9796 - val_loss: 0.0013 - val_pearson_correlation: 0.9693
# Epoch 261/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9786 - val_loss: 0.0014 - val_pearson_correlation: 0.9690
# Epoch 262/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9796 - val_loss: 0.0012 - val_pearson_correlation: 0.9696
# Epoch 263/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9743 - val_loss: 0.0012 - val_pearson_correlation: 0.9699
# Epoch 264/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9759 - val_loss: 0.0014 - val_pearson_correlation: 0.9692
# Epoch 265/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0013 - pearson_correlation: 0.9760 - val_loss: 0.0015 - val_pearson_correlation: 0.9689
# Epoch 266/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9785 - val_loss: 0.0015 - val_pearson_correlation: 0.9694
# Epoch 267/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9789 - val_loss: 0.0012 - val_pearson_correlation: 0.9696
# Epoch 268/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9786 - val_loss: 0.0013 - val_pearson_correlation: 0.9690
# Epoch 269/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9791 - val_loss: 0.0012 - val_pearson_correlation: 0.9696
# Epoch 270/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9784 - val_loss: 0.0015 - val_pearson_correlation: 0.9705
# Epoch 271/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9788 - val_loss: 0.0013 - val_pearson_correlation: 0.9682
# Epoch 272/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9805 - val_loss: 0.0013 - val_pearson_correlation: 0.9690
# Epoch 273/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9740 - val_loss: 0.0012 - val_pearson_correlation: 0.9680
# Epoch 274/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9781 - val_loss: 0.0017 - val_pearson_correlation: 0.9675
# Epoch 275/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0013 - pearson_correlation: 0.9779 - val_loss: 0.0012 - val_pearson_correlation: 0.9678
# Epoch 276/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9795 - val_loss: 0.0012 - val_pearson_correlation: 0.9686
# Epoch 277/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0011 - pearson_correlation: 0.9768 - val_loss: 0.0013 - val_pearson_correlation: 0.9691
# Epoch 278/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9759 - val_loss: 0.0012 - val_pearson_correlation: 0.9699
# Epoch 279/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0012 - pearson_correlation: 0.9782 - val_loss: 0.0012 - val_pearson_correlation: 0.9673
# Epoch 280/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9796 - val_loss: 0.0012 - val_pearson_correlation: 0.9692
# Epoch 281/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9793 - val_loss: 0.0012 - val_pearson_correlation: 0.9676
# Epoch 282/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9788 - val_loss: 0.0012 - val_pearson_correlation: 0.9640
# Epoch 283/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9756 - val_loss: 0.0012 - val_pearson_correlation: 0.9670
# Epoch 284/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9799 - val_loss: 0.0014 - val_pearson_correlation: 0.9677
# Epoch 285/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9796 - val_loss: 0.0012 - val_pearson_correlation: 0.9654
# Epoch 286/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9795 - val_loss: 0.0011 - val_pearson_correlation: 0.9690
# Epoch 287/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9768 - val_loss: 0.0015 - val_pearson_correlation: 0.9647
# Epoch 288/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9795 - val_loss: 0.0012 - val_pearson_correlation: 0.9715
# Epoch 289/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0013 - pearson_correlation: 0.9736 - val_loss: 0.0011 - val_pearson_correlation: 0.9705
# Epoch 290/450
# ...
# Epoch 355/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9781 - val_loss: 0.0012 - val_pearson_correlation: 0.9715
# Epoch 356/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9799 - val_loss: 0.0011 - val_pearson_correlation: 0.9703
# Epoch 357/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9800 - val_loss: 0.0013 - val_pearson_correlation: 0.9677
# Epoch 358/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9789 - val_loss: 0.0017 - val_pearson_correlation: 0.9682
# Epoch 359/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9783 - val_loss: 0.0012 - val_pearson_correlation: 0.9700
# Epoch 360/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9806 - val_loss: 0.0012 - val_pearson_correlation: 0.9666
# Epoch 361/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9800 - val_loss: 0.0011 - val_pearson_correlation: 0.9677
# Epoch 362/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9794 - val_loss: 0.0013 - val_pearson_correlation: 0.9703
# Epoch 363/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9787 - val_loss: 0.0012 - val_pearson_correlation: 0.9674
# Epoch 364/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9800 - val_loss: 0.0013 - val_pearson_correlation: 0.9700
# Epoch 365/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9806 - val_loss: 0.0012 - val_pearson_correlation: 0.9695
# Epoch 366/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9787 - val_loss: 0.0011 - val_pearson_correlation: 0.9707
# Epoch 367/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9817 - val_loss: 0.0012 - val_pearson_correlation: 0.9688
# Epoch 368/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9789 - val_loss: 0.0011 - val_pearson_correlation: 0.9715
# Epoch 369/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9785 - val_loss: 0.0012 - val_pearson_correlation: 0.9685
# Epoch 370/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9782 - val_loss: 0.0012 - val_pearson_correlation: 0.9707
# Epoch 371/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9786 - val_loss: 0.0013 - val_pearson_correlation: 0.9700
# Epoch 372/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9818 - val_loss: 0.0012 - val_pearson_correlation: 0.9712
# Epoch 373/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9798 - val_loss: 0.0012 - val_pearson_correlation: 0.9710
# Epoch 374/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9798 - val_loss: 0.0014 - val_pearson_correlation: 0.9689
# Epoch 375/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9814 - val_loss: 0.0011 - val_pearson_correlation: 0.9708
# Epoch 376/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9805 - val_loss: 0.0012 - val_pearson_correlation: 0.9693
# Epoch 377/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9804 - val_loss: 0.0013 - val_pearson_correlation: 0.9674
# Epoch 378/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9798 - val_loss: 0.0011 - val_pearson_correlation: 0.9668
# Epoch 379/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9818 - val_loss: 0.0012 - val_pearson_correlation: 0.9702
# Epoch 380/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9815 - val_loss: 0.0012 - val_pearson_correlation: 0.9693
# Epoch 381/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9784 - val_loss: 0.0015 - val_pearson_correlation: 0.9643
# Epoch 382/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9811 - val_loss: 0.0013 - val_pearson_correlation: 0.9717
# Epoch 383/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9802 - val_loss: 0.0012 - val_pearson_correlation: 0.9677
# Epoch 384/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9816 - val_loss: 0.0012 - val_pearson_correlation: 0.9708
# Epoch 385/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9813 - val_loss: 0.0011 - val_pearson_correlation: 0.9680
# Epoch 386/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9785 - val_loss: 0.0011 - val_pearson_correlation: 0.9705
# Epoch 387/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0011 - pearson_correlation: 0.9803 - val_loss: 0.0011 - val_pearson_correlation: 0.9715
# Epoch 388/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9798 - val_loss: 0.0016 - val_pearson_correlation: 0.9676
# Epoch 389/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0012 - pearson_correlation: 0.9817 - val_loss: 0.0011 - val_pearson_correlation: 0.9672
# Epoch 390/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9799 - val_loss: 0.0011 - val_pearson_correlation: 0.9698
# Epoch 391/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - pearson_correlation: 0.9803 - val_loss: 0.0014 - val_pearson_correlation: 0.9673
# Epoch 392/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9796 - val_loss: 0.0015 - val_pearson_correlation: 0.9693
# Epoch 393/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9804 - val_loss: 0.0012 - val_pearson_correlation: 0.9710
# Epoch 394/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0010 - pearson_correlation: 0.9782 - val_loss: 0.0013 - val_pearson_correlation: 0.9715
# Epoch 395/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9798 - val_loss: 0.0013 - val_pearson_correlation: 0.9693
# Epoch 396/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9803 - val_loss: 0.0013 - val_pearson_correlation: 0.9690
# Epoch 397/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9781 - val_loss: 0.0012 - val_pearson_correlation: 0.9679
# Epoch 398/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9778 - val_loss: 0.0013 - val_pearson_correlation: 0.9705
# Epoch 399/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9799 - val_loss: 0.0011 - val_pearson_correlation: 0.9712
# Epoch 400/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9741 - val_loss: 0.0012 - val_pearson_correlation: 0.9702
# Epoch 401/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9814 - val_loss: 0.0013 - val_pearson_correlation: 0.9682
# Epoch 402/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9792 - val_loss: 0.0012 - val_pearson_correlation: 0.9699
# Epoch 403/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - pearson_correlation: 0.9778 - val_loss: 0.0012 - val_pearson_correlation: 0.9727
# Epoch 404/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9814 - val_loss: 0.0011 - val_pearson_correlation: 0.9695
# Epoch 405/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9820 - val_loss: 0.0011 - val_pearson_correlation: 0.9703
# Epoch 406/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9774 - val_loss: 0.0014 - val_pearson_correlation: 0.9706
# Epoch 407/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9786 - val_loss: 0.0011 - val_pearson_correlation: 0.9701
# Epoch 408/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - pearson_correlation: 0.9817 - val_loss: 0.0011 - val_pearson_correlation: 0.9701
# Epoch 409/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9808 - val_loss: 0.0011 - val_pearson_correlation: 0.9695
# Epoch 410/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9807 - val_loss: 0.0011 - val_pearson_correlation: 0.9704
# Epoch 411/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9833 - val_loss: 0.0013 - val_pearson_correlation: 0.9718
# Epoch 412/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9811 - val_loss: 0.0011 - val_pearson_correlation: 0.9715
# Epoch 413/450
# 45/45 [==============================] - 2s 34ms/step - loss: 0.0011 - pearson_correlation: 0.9782 - val_loss: 0.0011 - val_pearson_correlation: 0.9721
# Epoch 414/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9800 - val_loss: 0.0015 - val_pearson_correlation: 0.9679
# Epoch 415/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9807 - val_loss: 0.0011 - val_pearson_correlation: 0.9681
# Epoch 416/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9775 - val_loss: 0.0011 - val_pearson_correlation: 0.9711
# Epoch 417/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9771 - val_loss: 0.0011 - val_pearson_correlation: 0.9709
# Epoch 418/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9824 - val_loss: 0.0011 - val_pearson_correlation: 0.9705
# Epoch 419/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - pearson_correlation: 0.9820 - val_loss: 0.0011 - val_pearson_correlation: 0.9715
# Epoch 420/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9823 - val_loss: 0.0011 - val_pearson_correlation: 0.9717
# Epoch 421/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - pearson_correlation: 0.9818 - val_loss: 0.0011 - val_pearson_correlation: 0.9704
# Epoch 422/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9812 - val_loss: 0.0014 - val_pearson_correlation: 0.9702
# Epoch 423/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0012 - pearson_correlation: 0.9777 - val_loss: 0.0012 - val_pearson_correlation: 0.9680
# Epoch 424/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9787 - val_loss: 0.0011 - val_pearson_correlation: 0.9705
# Epoch 425/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9779 - val_loss: 0.0012 - val_pearson_correlation: 0.9717
# Epoch 426/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9778 - val_loss: 0.0012 - val_pearson_correlation: 0.9722
# Epoch 427/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9817 - val_loss: 0.0012 - val_pearson_correlation: 0.9685
# Epoch 428/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9788 - val_loss: 0.0011 - val_pearson_correlation: 0.9707
# Epoch 429/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - pearson_correlation: 0.9789 - val_loss: 0.0011 - val_pearson_correlation: 0.9703
# Epoch 430/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9808 - val_loss: 0.0012 - val_pearson_correlation: 0.9688
# Epoch 431/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9823 - val_loss: 0.0011 - val_pearson_correlation: 0.9697
# Epoch 432/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9800 - val_loss: 0.0014 - val_pearson_correlation: 0.9679
# Epoch 433/450
# 45/45 [==============================] - 2s 45ms/step - loss: 0.0011 - pearson_correlation: 0.9824 - val_loss: 0.0013 - val_pearson_correlation: 0.9691
# Epoch 434/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9826 - val_loss: 0.0012 - val_pearson_correlation: 0.9693
# Epoch 435/450
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0012 - pearson_correlation: 0.9784 - val_loss: 0.0012 - val_pearson_correlation: 0.9668
# Epoch 436/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0010 - pearson_correlation: 0.9814 - val_loss: 0.0011 - val_pearson_correlation: 0.9704
# Epoch 437/450
# 45/45 [==============================] - 2s 38ms/step - loss: 0.0010 - pearson_correlation: 0.9821 - val_loss: 0.0014 - val_pearson_correlation: 0.9690
# Epoch 438/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - pearson_correlation: 0.9793 - val_loss: 0.0012 - val_pearson_correlation: 0.9695
# Epoch 439/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0011 - pearson_correlation: 0.9785 - val_loss: 0.0011 - val_pearson_correlation: 0.9701
# Epoch 440/450
# 45/45 [==============================] - 2s 36ms/step - loss: 9.9417e-04 - pearson_correlation: 0.9809 - val_loss: 0.0012 - val_pearson_correlation: 0.9688
# Epoch 441/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0011 - pearson_correlation: 0.9808 - val_loss: 0.0012 - val_pearson_correlation: 0.9695
# Epoch 442/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - pearson_correlation: 0.9803 - val_loss: 0.0011 - val_pearson_correlation: 0.9717
# Epoch 443/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9807 - val_loss: 0.0015 - val_pearson_correlation: 0.9682
# Epoch 444/450
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0010 - pearson_correlation: 0.9811 - val_loss: 0.0012 - val_pearson_correlation: 0.9697
# Epoch 445/450
# 45/45 [==============================] - 2s 37ms/step - loss: 9.9872e-04 - pearson_correlation: 0.9834 - val_loss: 0.0011 - val_pearson_correlation: 0.9708
# Epoch 446/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - pearson_correlation: 0.9801 - val_loss: 0.0013 - val_pearson_correlation: 0.9662
# Epoch 447/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0011 - pearson_correlation: 0.9808 - val_loss: 0.0011 - val_pearson_correlation: 0.9725
# Epoch 448/450
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0010 - pearson_correlation: 0.9815 - val_loss: 0.0011 - val_pearson_correlation: 0.9691
# Epoch 449/450
# 45/45 [==============================] - 2s 37ms/step - loss: 9.9382e-04 - pearson_correlation: 0.9805 - val_loss: 0.0011 - val_pearson_correlation: 0.9722
# Epoch 450/450
# 45/45 [==============================] - 2s 36ms/step - loss: 0.0010 - pearson_correlation: 0.9815 - val_loss: 0.0014 - val_pearson_correlation: 0.9694

# %%
#predict the abundances
predictedAbundances=jointAbundanceEstimator.predict(preprocessedSpectra[testingIndices,:])
# Out:
# 12/12 [==============================] - 2s 132ms/step

# %%
#get the actual abundances for the test samples
actualTestAbundances=atomicAbundances[testingIndices,:]

# %%
#iterate through all the elements
for i in range(actualTestAbundances.shape[1]):
    #get the actual and predicted abundances for the current element
    currentElementPredictedAbundances=predictedAbundances[:,i]
    currentElementActualAbundances=actualTestAbundances[:,i]
    #compute the correlation between the actual and predicted abundances
    currentElementCorrelation=np.corrcoef(currentElementPredictedAbundances,
                                          currentElementActualAbundances)[0,1]
    #get the name of the current element
    currentElementName=elementNames[i]
    #print the element's name and the correlation between its actual and predicted abundances
    print(f"{currentElementName}--{round(currentElementCorrelation,2)}")
# Out:
# Potassium--0.98
# Uranium--0.98
# Thorium--0.99
