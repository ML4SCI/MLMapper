# %%
#expand cell width to 100%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#import pandas 
import pandas as pd
#import numpy
import numpy as np

# %%
#set the address of the dataframe containing the pre-processed dataset
dataFramePickleAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Dataset/GRSFiveDegreeSectionPreProcessedDataset.pkl"

# %%
#read the dataframe
dataframe=pd.read_pickle(dataFramePickleAddress)

# %%
#print the dataframe
dataframe
# Out:
#       Max Lat per section  Min Lat per section  Max Lon per section  \
# 0                   -87.5                -90.0                180.0
# 1                   -82.5                -87.5               -135.0
# 2                   -82.5                -87.5                -90.0
# 3                   -82.5                -87.5                -45.0
# 4                   -82.5                -87.5                  0.0
# ...                   ...                  ...                  ...
# 1785                 87.5                 82.5                 45.0
# 1786                 87.5                 82.5                 90.0
# 1787                 87.5                 82.5                135.0
# 1788                 87.5                 82.5                180.0
# 1789                 90.0                 87.5                180.0
#
#       Min Lon per section  No. of spectra per section  \
# 0                  -180.0                        7002
# 1                  -180.0                        1599
# 2                  -135.0                        1940
# 3                   -90.0                        1818
# 4                   -45.0                        1855
# ...                   ...                         ...
# 1785                  0.0                        1748
# 1786                 45.0                        2035
# 1787                 90.0                        1903
# 1788                135.0                        1902
# 1789               -180.0                        7294
#
#       Total active time per section  \
# 0                     215153.707937
# 1                      49113.391313
# 2                      59600.854365
# 3                      55864.552890
# 4                      57007.157885
# ...                             ...
# 1785                   53653.126808
# 1786                   62483.348769
# 1787                   58474.988092
# 1788                   58399.244640
# 1789                  223993.416783
#
#                                          Summed Spectra  \
# 0     [270112.3731329723, 44221.71628033137, 45327.9...
# 1     [101728.76450092324, 11353.802617173642, 10565...
# 2     [69004.10988058499, 13041.311258502305, 12455....
# 3     [51455.21453525051, 11348.088811988011, 11487....
# 4     [51138.233213284286, 10203.879826977849, 12005...
# ...                                                 ...
# 1785  [172204.68795185376, 12837.986652251333, 11392...
# 1786  [69631.4865040512, 13027.290796013549, 12597.1...
# 1787  [58870.11519813659, 11691.651373354718, 11794....
# 1788  [69077.49428235987, 10543.676356979646, 11999....
# 1789  [342422.3644296753, 45978.50919445278, 45791.6...
#
#                                      Normalized Spectra  \
# 0     [75.32634479500912, 12.332127585726989, 12.640...
# 1     [124.27824075904886, 13.87051756806718, 12.906...
# 2     [69.4662289143658, 13.12864863838364, 12.53878...
# 3     [55.264254565457236, 12.188146033430378, 12.33...
# 4     [53.82296024948041, 10.739577490433051, 12.635...
# ...                                                 ...
# 1785  [192.57556626933405, 14.356650673799725, 12.73...
# 1786  [66.8640409410214, 12.509531949810704, 12.0964...
# 1787  [60.40543191435932, 11.996566485773727, 12.102...
# 1788  [70.97094632772614, 10.832684314943478, 12.328...
# 1789  [91.72297186611817, 12.316034066037092, 12.265...
#
#                                  Log Normalized Spectra  Aluminum  ...  \
# 0     [1.8769468938381042, 1.0910380092016139, 1.101...    15.151  ...
# 1     [2.0943950968999223, 1.1420926667518603, 1.110...    13.394  ...
# 2     [1.8417737231418783, 1.118220025472807, 1.0982...    13.634  ...
# 3     [1.742444316396172, 1.085937649122431, 1.09122...    14.642  ...
# 4     [1.7309675801735431, 1.030987195964759, 1.1015...    14.030  ...
# ...                                                 ...       ...  ...
# 1785  [2.2846011835800297, 1.1570531332525222, 1.105...    14.908  ...
# 1786  [1.8251926197192418, 1.0972410606592737, 1.082...    14.201  ...
# 1787  [1.781075993991352, 1.07905696524328, 1.082869...    14.718  ...
# 1788  [1.8510805961570183, 1.0347360871623914, 1.090...    15.137  ...
# 1789  [1.962478117625136, 1.0904708814873694, 1.0887...    15.185  ...
#
#       Magnesium  Oxygen  Potassium  Silicon  Thorium  Titanium  Uranium  \
# 0        3.5168  45.289     299.99   20.793  0.46453   0.17034  0.17684
# 1        4.2240  45.529     376.77   22.029  0.65727   0.11806  0.14017
# 2        3.5352  44.660     375.20   20.907  0.59783   0.16417  0.25209
# 3        3.6490  44.706     255.60   20.687  0.44024   0.21359  0.15456
# 4        3.4253  44.777     299.84   20.930  0.41695   0.00000  0.17853
# ...         ...     ...        ...      ...      ...       ...      ...
# 1785     4.8716  44.940     935.92   20.180  1.65770   0.11112  0.47992
# 1786     4.9509  45.074     725.37   20.989  1.47520   0.23089  0.31377
# 1787     3.5729  44.902     615.29   20.763  1.13880   0.14168  0.36836
# 1788     3.4631  45.209     534.21   20.913  0.92528   0.14485  0.24324
# 1789     4.2786  44.799     714.98   20.098  1.31050   0.14671  0.41704
#
#                             Denoised Log Scaled Spectra  \
# 0     [2.158214838616408, 2.157544331369737, 2.15556...
# 1     [2.166600464940364, 2.1658480356144825, 2.1637...
# 2     [2.1624604406884194, 2.1617557577637347, 2.159...
# 3     [2.156835106449848, 2.156137776072336, 2.15427...
# 4     [2.1550525786763455, 2.15430812063849, 2.15245...
# ...                                                 ...
# 1785  [2.15549824869262, 2.1548999596086973, 2.15302...
# 1786  [2.14741575183071, 2.14686561246586, 2.1451899...
# 1787  [2.1464838830391613, 2.1458006278534687, 2.143...
# 1788  [2.1390119880861276, 2.138304773247351, 2.1364...
# 1789  [2.1479502451595986, 2.147254910678402, 2.1453...
#
#           Continuum Removed Denoised Log Scaled Spectra  \
# 0     [0.0, 0.0031096864344261066, 0.005679290051129...
# 1     [0.0, 0.0031162181188209015, 0.005685493606940...
# 2     [0.0, 0.003128077634203974, 0.0057268713902404...
# 3     [0.0, 0.0031223821127568385, 0.005761526562635...
# 4     [0.0, 0.0030380779680346803, 0.005615903444584...
# ...                                                 ...
# 1785  [0.0, 0.0031042509343501834, 0.005683791947784...
# 1786  [0.0, 0.003080477682960492, 0.0056969814199795...
# 1787  [0.0, 0.003018919479894744, 0.0055261654685280...
# 1788  [0.0, 0.0029927682042373283, 0.005525986008764...
# 1789  [0.0, 0.003031719365600205, 0.0055773123862935...
#
#      Normalized Continuum Removed Denoised Log Scaled Spectra
# 0     [0.0, 0.008732596361173385, 0.0159485365101445...
# 1     [0.0, 0.00854362748004175, 0.01558772125881830...
# 2     [0.0, 0.008671523159558032, 0.0158757881675521...
# 3     [0.0, 0.008548415452029046, 0.0157738293766423...
# 4     [0.0, 0.00860571082569534, 0.01590770269151066...
# ...                                                 ...
# 1785  [0.0, 0.008672476703310141, 0.0158790491800041...
# 1786  [0.0, 0.008773223933367814, 0.0162250465303427...
# 1787  [0.0, 0.008498570047967925, 0.0155567263862845...
# 1788  [0.0, 0.008238164470285638, 0.0152113289416292...
# 1789  [0.0, 0.008583538074052393, 0.0157907337208821...
#
# [1790 rows x 22 columns]

# %%
#create a variable epsilon, which contains a very small value that is added to all inputs and outputs to make sure no values are 0
epsilon=1e-8

# %%
#get the abundance values for the seven elements for which the model is to be trained
#aluminium
aluminiumAbundances=dataframe['Aluminum'].to_numpy()+epsilon
#calcium
calciumAbundances=dataframe['Calcium'].to_numpy()+epsilon
#iron
ironAbundances=dataframe['Iron'].to_numpy()+epsilon
#magnesium
magnesiumAbundances=dataframe['Magnesium'].to_numpy()+epsilon
#oxygen
oxygenAbundances=dataframe['Oxygen'].to_numpy()+epsilon
#silicon
siliconAbundances=dataframe['Silicon'].to_numpy()+epsilon
#titanium
titaniumAbundances=dataframe['Titanium'].to_numpy()+epsilon

# %%
#create an list which contains the element names to be estimated
elementNames=['Aluminum',
              'Calcium',
              'Iron',
              'Magnesium',
              'Oxygen',
              'Silicon',
              'Titanium']
#conver the list to a numpy array
elementNames=np.array(elementNames)

# %%
#combine the elemental abundances into a single matrix
allElementalAbundances=np.dstack([aluminiumAbundances,
                                  calciumAbundances,
                                  ironAbundances,
                                  magnesiumAbundances,
                                  oxygenAbundances,
                                  siliconAbundances,
                                  titaniumAbundances])
#reshape the abundance matrix
allElementalAbundances=allElementalAbundances[0,:,:]
#rescale weigth percent values from % (0-100) to franctions (0-1)
allElementalAbundances=allElementalAbundances/100

# %%
#read the pre-processed spectra as a numpy array
preprocessedSpectra=dataframe['Normalized Continuum Removed Denoised Log Scaled Spectra'].to_numpy()
#reshape the numpy array
preprocessedSpectra=np.vstack(preprocessedSpectra)+epsilon

# %%
#compute the eneergy values for each band
gain=17.8 #keV/channel
energyBands=np.arange(0,512,1)*gain

# %%
#get the index of the last relavent band
finalRelaventBandIndex=np.argmin(np.abs(energyBands-8000))
#compute the index of the first relavent band
firstRelaventBandIndex=finalRelaventBandIndex-preprocessedSpectra.shape[1]+1
#get the energies of the relavent bands
relaventEnergyBands=energyBands[firstRelaventBandIndex:finalRelaventBandIndex+1]

# %%
#remove the variables no longer needed from memory
del firstRelaventBandIndex
del finalRelaventBandIndex
del energyBands
del gain
del dataframe
del dataFramePickleAddress
del aluminiumAbundances
del calciumAbundances
del ironAbundances
del magnesiumAbundances
del oxygenAbundances
del siliconAbundances
del titaniumAbundances

# %%
#import pyplot from matplotlib
import matplotlib.pyplot as plt

# %%
#set plot parameters
baseFontSize=18
noOfBinsForHistogram=100
noOfXticks=5

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=7,
                         figsize=(35,5),
                         dpi=200)
#iterate over all elements
for i in range(elementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(allElementalAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(elementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("Wt frac.",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(allElementalAbundances[:,i]),
                                 np.amax(allElementalAbundances[:,i])+np.ptp(allElementalAbundances[:,i])/noOfXticks,
                                 np.ptp(allElementalAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(allElementalAbundances[:,i]),
                                                 np.amax(allElementalAbundances[:,i])+np.ptp(allElementalAbundances[:,i])/noOfXticks,
                                                 np.ptp(allElementalAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure
plt.figure(figsize=(30,15),
           dpi=100)
#and plot all the spectra
for i in range(preprocessedSpectra.shape[0]):
    plt.plot(relaventEnergyBands,
             preprocessedSpectra[i,:],
             lw=5)
#annotate the figure
plt.title("Preprocessed GRS Spectra",
          fontsize=baseFontSize*1.8)
plt.xticks(np.arange(np.amin(relaventEnergyBands),
                     np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                     np.ptp(relaventEnergyBands)/noOfXticks),
           fontsize=baseFontSize*1.2)
plt.yticks(np.arange(np.amin(preprocessedSpectra),
                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                     np.ptp(preprocessedSpectra)/noOfXticks),
           labels=np.round(np.arange(np.amin(preprocessedSpectra),
                                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                                     np.ptp(preprocessedSpectra)/noOfXticks),
                           2),
           fontsize=baseFontSize*1.2)
plt.xlabel("KeV",
           fontsize=baseFontSize*1.5)
plt.ylabel("log(Counts/min) ratioed",
           fontsize=baseFontSize*1.5)
plt.margins(0)

# %%
#import tensorflow
import tensorflow as tf

# %%
#set a global seed value
globalSeed=23

# %%
#load the pre-trained models
#define a funtion to calculate the Pearsons correlation between two sets of values
def pearson_correlation(x,y):
    x_mean=tf.reduce_mean(x)
    y_mean=tf.reduce_mean(y)
    x_diff=x-x_mean
    y_diff=y-y_mean
    covariance=tf.reduce_mean(tf.multiply(x_diff,y_diff))
    x_std=tf.sqrt(tf.reduce_mean(tf.square(x_diff)))
    y_std=tf.sqrt(tf.reduce_mean(tf.square(y_diff)))
    correlation=covariance/(x_std*y_std)
    return correlation

# %%
# define a funtion which creates the CAM (Channel Attention Module)
def createCAM(inputFeatureBlock,reductionRatio):
    #perform max pooling along the channel dimension
    channelMaxPooledFeatures=tf.math.reduce_max(inputFeatureBlock,
                                                axis=1,
                                                keepdims=False)
    
    #perform avg pooling along the channel dimension
    channelAvgPooledFeatures=tf.math.reduce_mean(inputFeatureBlock,
                                                 axis=1,
                                                 keepdims=False)
    
    #create the bottleneck for the MLP
    bottleneckLayer=tf.keras.layers.Dense(channelAvgPooledFeatures.shape[-1]//reductionRatio,
                                          activation='relu')
    
    #create the recontruction layer for the MLP
    outputLayer=tf.keras.layers.Dense(channelAvgPooledFeatures.shape[-1],
                                      activation='relu')
    
    #create a dropout layer for both MLP layers
    bottleNeckDropout=tf.keras.layers.Dropout(0.5,
                                              noise_shape=None,
                                              seed=globalSeed)
    
    OutputDropout=tf.keras.layers.Dropout(0.5,
                                          noise_shape=None,
                                          seed=globalSeed)
    
    #pass the max pooled features through the bottle-neck
    reconstructeedMaxPooledFeatures=outputLayer(bottleneckLayer(channelMaxPooledFeatures))
    
    
    #pass the avg pooled features through the bottle-neck
    reconstructeedAvgPooledFeatures=outputLayer(bottleneckLayer(channelMaxPooledFeatures))
    
    
    #add the two reconstructed features together
    summedFeatures=tf.math.add(reconstructeedMaxPooledFeatures,
                               reconstructeedAvgPooledFeatures)
    
    #apply sigmoid activation to the summed features to get the channel attention map
    channelAttentionMap=tf.keras.activations.sigmoid(summedFeatures)
    
    #return the channel attention map
    return channelAttentionMap

# %%
#define a function to create the Spatial attention module (SAM)
def createSAM(inputFeatureBlock,kernelSize):
    #perform max pooling on the input features
    maxPooledFeatureMap=tf.math.reduce_max(inputFeatureBlock,
                                           axis=-1,
                                           keepdims=False)
    #perform average pooling on the input features
    averagePooledFeatureMap=tf.math.reduce_mean(inputFeatureBlock,
                                                 axis=-1,
                                                 keepdims=False)
    
    #concatenate the feature maps together
    concatenatedFeatureMaps=tf.concat([tf.expand_dims(maxPooledFeatureMap,
                                                      axis=-1),
                                       tf.expand_dims(averagePooledFeatureMap,
                                                      axis=-1)],
                                      axis=-1)
    
    #create the convolutional layer to be applied to the concatenated feature map
    convolutionLayer=tf.keras.layers.Conv1D(filters=1,
                                            kernel_size=kernelSize,
                                            strides=1,
                                            padding='same',
                                            activation='sigmoid')
    #create and add a dropout layer
    spatialDropoutLayer=tf.keras.layers.Dropout(0.5,
                                                noise_shape=None,
                                                seed=globalSeed)
    
    
    #get the spatial attention map
    spatialAttentionMap=convolutionLayer(concatenatedFeatureMaps)
    
    
    #return the channel attention map
    return spatialAttentionMap

# %%
#define a function which creates a CBAM block
def createCBAM(inputLayer,convolutionalKernelSize,noOfConvolutionalFilters,reductionRatio,spatialKernelSize):
    #create a convolutional layer
    convolutionalLayer=tf.keras.layers.Conv1D(filters=noOfConvolutionalFilters,
                                              kernel_size=convolutionalKernelSize,
                                              strides=1,
                                              padding='same')
    #get the feature block from the convolutional layer
    convolutionalFeatures=convolutionalLayer(inputLayer)
    
    #get the channel attention map
    channelAttentionMap=createCAM(convolutionalFeatures,
                                  reductionRatio)
    
    #replicate the channel attention to make it multiplicative with the features
    replicatedChannelAttentionMaps=tf.expand_dims(channelAttentionMap,
                                                  axis=1)
    replicatedChannelAttentionMaps=tf.repeat(replicatedChannelAttentionMaps,
                                             convolutionalFeatures.shape[1],
                                             axis=1)
    
    #compute the channel refined feature by performing element-wise multiplication between the features and the channel attention maps
    channelRefinedFeatures=tf.math.multiply(replicatedChannelAttentionMaps,
                                            convolutionalFeatures)
    
    '''
    #apply batch norm to the refined features
    channelRefinedFeatures=tf.keras.layers.BatchNormalization()(channelRefinedFeatures)
    '''
    
    #get the spatial attention map
    spatialAttentionMap=createSAM(channelRefinedFeatures,
                                  spatialKernelSize)
    
    #replicate the attention map to make it multiplicative with the channel-refined features
    replicatedSpatialAttentionMaps=tf.repeat(spatialAttentionMap,
                                             channelRefinedFeatures.shape[-1],
                                             axis=-1)
    
    #multiply the attention map with the channel refined features
    spatiallyRefinedFeatures=tf.math.multiply(replicatedSpatialAttentionMaps,
                                              channelRefinedFeatures)
    
    '''
    #apply batch norm to the refined features
    spatiallyRefinedFeatures=tf.keras.layers.BatchNormalization()(spatiallyRefinedFeatures)
    '''
    
    
    #add the refined features to the original features
    refinedFeatures=tf.math.add(convolutionalFeatures,
                                spatiallyRefinedFeatures)
    
    #return the refined features (i.e. the output of the CBAM)
    return refinedFeatures

# %%
#compute the number of channels in the pre-processed spectra
noOfChannels=preprocessedSpectra.shape[1]

# %%
#create an input layer
inputLayer=tf.keras.Input(shape=(noOfChannels,
                                 1))

# %%
#create a NN (Neural Network) graph containing just the input layer
nnGraph=inputLayer

# %%
#create a convolutional block
firstConvolutionalLayer=tf.keras.layers.Conv1D(filters=64,
                                               kernel_size=7,
                                               strides=1,
                                               padding='same',
                                               name="1st_Conv_layer")
#add the 1st Conv layer to the graph
nnGraph=firstConvolutionalLayer(nnGraph)

#apply Relu activation
firstReluActivation=tf.keras.layers.Activation('relu',
                                               name="1st_Activation")
#add the 1st activation layer to the graph
nnGraph=firstReluActivation(nnGraph)

#apply batch normalization
firstBatchNormalization=tf.keras.layers.BatchNormalization(name="1st_Batch_Norm")
#add the 1st batch-norm layer to the graph
nnGraph=firstBatchNormalization(nnGraph)

#apply dropout
firstDropoutLayer=tf.keras.layers.Dropout(0.5,
                                          noise_shape=None,
                                          seed=globalSeed,
                                          name="1st_Dropout")
#add the 1st dropout layer to the graph
nnGraph=firstDropoutLayer(nnGraph)

# %%
#create a list containing the number of features to be outputted by each CBAM block
noOfChannelsInEachCBAMBlock=[64,64,64,64,
                             128,128,128,128,
                             256,256,256,256,
                             512,512,512,512]

# %%
#iterate through all the number of channels and add CBAM blocks
for i in range(len(noOfChannelsInEachCBAMBlock)):
    #get the current number of channels 
    currentNumberOfChannels=noOfChannelsInEachCBAMBlock[i]
    #add a CBAM block to the network
    nnGraph=createCBAM(nnGraph,
                       convolutionalKernelSize=3,
                       noOfConvolutionalFilters=currentNumberOfChannels,
                       reductionRatio=6,spatialKernelSize=7)

    #create a flag indicating if the features are to be pooled
    performPooling=False
    try:
        #check if the number of of channels changes in the next block, if so set the pooling flag to true
        if noOfChannelsInEachCBAMBlock[i]!=noOfChannelsInEachCBAMBlock[i+1]:
            performPooling=True
    except:
        performPooling=False
    #check if the flag is true, if it is perform average pooling
    if performPooling:
        nnGraph=tf.keras.layers.AveragePooling1D(pool_size=2)(nnGraph)
    
    #print the shape of the current tensor
    print(f"Shape of the tensor outputted by the {i}th CBAM block #{nnGraph.shape}")
# Out:
# Shape of the tensor outputted by the 0th CBAM block #(None, 421, 64)
# Shape of the tensor outputted by the 1th CBAM block #(None, 421, 64)
# Shape of the tensor outputted by the 2th CBAM block #(None, 421, 64)
# Shape of the tensor outputted by the 3th CBAM block #(None, 210, 64)
# Shape of the tensor outputted by the 4th CBAM block #(None, 210, 128)
# Shape of the tensor outputted by the 5th CBAM block #(None, 210, 128)
# Shape of the tensor outputted by the 6th CBAM block #(None, 210, 128)
# Shape of the tensor outputted by the 7th CBAM block #(None, 105, 128)
# Shape of the tensor outputted by the 8th CBAM block #(None, 105, 256)
# Shape of the tensor outputted by the 9th CBAM block #(None, 105, 256)
# Shape of the tensor outputted by the 10th CBAM block #(None, 105, 256)
# Shape of the tensor outputted by the 11th CBAM block #(None, 52, 256)
# Shape of the tensor outputted by the 12th CBAM block #(None, 52, 512)
# Shape of the tensor outputted by the 13th CBAM block #(None, 52, 512)
# Shape of the tensor outputted by the 14th CBAM block #(None, 52, 512)
# Shape of the tensor outputted by the 15th CBAM block #(None, 52, 512)

# %%
#perform global average pooling
nnGraph=tf.keras.layers.GlobalAveragePooling1D()(nnGraph)

# %%
#print the shape of the average pooled features
print(f"No. of nodes outputted by the Global pooling layer {nnGraph.shape}")
# Out:
# No. of nodes outputted by the Global pooling layer (None, 512)

# %%
#add a fully connected layer to the network (output layer)
outputLayer=tf.keras.layers.Dense(7,
                                  activation='relu',
                                  name="7_Element_Abundance_Embedding")
nnGraph=outputLayer(nnGraph)

# %%
#define a function which given the output of a layer, ensures the sum of the values is one
#it does this by computing the sum of the nodes and dividing each note by it
def estimateAbundances(inputNodes):
    sampleWiseSums=tf.keras.backend.sum(inputNodes,
                                        axis=-1,
                                        keepdims=True)
    sampleWiseSums=tf.repeat(sampleWiseSums,
                             sampleWiseSums.shape[-1],
                             axis=-1)
    return inputNodes/(sampleWiseSums+1e-10)

# %%
#add a normalization layer to the network
abundanceValues=estimateAbundances(nnGraph)
nnGraph=abundanceValues

# %%
#print the shape of the output layer
print(f"No. of nodes in the output layer {nnGraph.shape}")
# Out:
# No. of nodes in the output layer (None, 7)

# %%
#build the model
jointAbundanceEstimator=tf.keras.Model(inputs=inputLayer,
                                       outputs=[nnGraph],
                                       name="Multitask_Abundance_estimator")

# %%
#create the loss function for the embedding, Mean Squared Error
lossFunction=tf.keras.losses.MeanSquaredError()
#create the optimizer
optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4)
#set the number of epochs the model is to be trained for
noOfEpochs=148
#set the batch size
batchSize=32

# %%
#compile the model
jointAbundanceEstimator.compile(optimizer=optimizer,
                                loss=lossFunction,
                                metrics=[pearson_correlation],
                                steps_per_execution=45)

# %%
#set the address where the untrained model will be saved
untrainedModelAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Joint_Abundance_Attention_Model.h5"

# %%
#save the untrained model
tf.keras.models.save_model(jointAbundanceEstimator,
                           untrainedModelAddress,
                           overwrite=True)

# %%
#import KFold from sklearn, to be used for KFold validation
from sklearn.model_selection import KFold

# %%
#set no. of folds over which the model is to be validated
noOfFolds=5

# %%
#create a K-Fold splitter
splitter=KFold(n_splits=noOfFolds,
               shuffle=True,
               random_state=globalSeed)

# %%
#check if the GPU is available
if len(tf.config.list_physical_devices('GPU'))==1:
    print("GPU available")
else:
    print("GPU unavailable")
# Out:
# GPU available

# %%
#create a list to hold model training history
modelTrainingHistories=[]
#create a list to store the trained models
trainedModels=[]

# %%
#iterate through the folds
for i,(trainingIndices,testingIndices) in enumerate(splitter.split(allElementalAbundances[:,0])):
    #print the current fold number
    print(f"Starting processing fold {i+1}")
    
    #build the model
    jointAbundanceEstimator=tf.keras.Model(inputs=inputLayer,
                                       outputs=[abundanceValues],
                                       name="Multitask_Abundance_estimator")
    
    #compile the model
    jointAbundanceEstimator.compile(optimizer=optimizer,
                                loss=lossFunction,
                                metrics=[pearson_correlation],
                                steps_per_execution=45)
    
    #fit the model to the current fold's data
    currentModelTrainingHistory=jointAbundanceEstimator.fit(x=preprocessedSpectra[trainingIndices,:],
                                                            y=allElementalAbundances[trainingIndices,:],
                                                            batch_size=batchSize,
                                                            epochs=noOfEpochs,
                                                            validation_data=(preprocessedSpectra[testingIndices,:],
                                                                             allElementalAbundances[testingIndices,:]),
                                                            validation_freq=1)
                                                            
    
    #save the training history of the current model
    modelTrainingHistories.append(currentModelTrainingHistory)
    
    
    #set the address where the trained model from the current 
    currentFoldTrainedModelAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Joint_Abundance_Attention_Model"+str(i+1)+".h5"
    
    #save the trained model
    trainedModels.append(jointAbundanceEstimator)
    
    break
# Out:
# Starting processing fold 1
# Epoch 1/148
# 45/45 [==============================] - 34s 753ms/step - loss: 0.0067 - pearson_correlation: 0.8658 - val_loss: 0.0030 - val_pearson_correlation: 0.9232
# Epoch 2/148
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0024 - pearson_correlation: 0.9434 - val_loss: 0.0028 - val_pearson_correlation: 0.9286
# Epoch 3/148
# 45/45 [==============================] - 6s 136ms/step - loss: 0.0024 - pearson_correlation: 0.9436 - val_loss: 0.0029 - val_pearson_correlation: 0.9256
# Epoch 4/148
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0023 - pearson_correlation: 0.9452 - val_loss: 0.0028 - val_pearson_correlation: 0.9280
# Epoch 5/148
# 45/45 [==============================] - 6s 127ms/step - loss: 0.0023 - pearson_correlation: 0.9466 - val_loss: 0.0028 - val_pearson_correlation: 0.9260
# Epoch 6/148
# 45/45 [==============================] - 6s 130ms/step - loss: 0.0022 - pearson_correlation: 0.9476 - val_loss: 0.0028 - val_pearson_correlation: 0.9262
# Epoch 7/148
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0012 - pearson_correlation: 0.9714 - val_loss: 0.0010 - val_pearson_correlation: 0.9778
# Epoch 8/148
# 45/45 [==============================] - 6s 127ms/step - loss: 2.4464e-04 - pearson_correlation: 0.9936 - val_loss: 7.0156e-04 - val_pearson_correlation: 0.9842
# Epoch 9/148
# 45/45 [==============================] - 6s 127ms/step - loss: 2.1700e-04 - pearson_correlation: 0.9943 - val_loss: 5.3033e-04 - val_pearson_correlation: 0.9888
# Epoch 10/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.9978e-04 - pearson_correlation: 0.9948 - val_loss: 4.5834e-04 - val_pearson_correlation: 0.9895
# Epoch 11/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.9877e-04 - pearson_correlation: 0.9948 - val_loss: 2.8046e-04 - val_pearson_correlation: 0.9932
# Epoch 12/148
# 45/45 [==============================] - 6s 137ms/step - loss: 1.9485e-04 - pearson_correlation: 0.9949 - val_loss: 2.7517e-04 - val_pearson_correlation: 0.9935
# Epoch 13/148
# 45/45 [==============================] - 6s 136ms/step - loss: 1.8609e-04 - pearson_correlation: 0.9951 - val_loss: 2.1601e-04 - val_pearson_correlation: 0.9946
# Epoch 14/148
# 45/45 [==============================] - 7s 152ms/step - loss: 1.8278e-04 - pearson_correlation: 0.9952 - val_loss: 1.8414e-04 - val_pearson_correlation: 0.9954
# Epoch 15/148
# 45/45 [==============================] - 6s 141ms/step - loss: 1.7731e-04 - pearson_correlation: 0.9953 - val_loss: 1.7631e-04 - val_pearson_correlation: 0.9955
# Epoch 16/148
# 45/45 [==============================] - 6s 141ms/step - loss: 1.7563e-04 - pearson_correlation: 0.9954 - val_loss: 1.7339e-04 - val_pearson_correlation: 0.9956
# Epoch 17/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.6789e-04 - pearson_correlation: 0.9956 - val_loss: 1.6516e-04 - val_pearson_correlation: 0.9958
# Epoch 18/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.6876e-04 - pearson_correlation: 0.9956 - val_loss: 1.6199e-04 - val_pearson_correlation: 0.9959
# Epoch 19/148
# 45/45 [==============================] - 6s 137ms/step - loss: 1.6817e-04 - pearson_correlation: 0.9956 - val_loss: 1.6210e-04 - val_pearson_correlation: 0.9959
# Epoch 20/148
# 45/45 [==============================] - 6s 135ms/step - loss: 1.6613e-04 - pearson_correlation: 0.9956 - val_loss: 1.5991e-04 - val_pearson_correlation: 0.9959
# Epoch 21/148
# 45/45 [==============================] - 6s 135ms/step - loss: 1.6553e-04 - pearson_correlation: 0.9957 - val_loss: 1.5327e-04 - val_pearson_correlation: 0.9961
# Epoch 22/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.6472e-04 - pearson_correlation: 0.9957 - val_loss: 1.5991e-04 - val_pearson_correlation: 0.9960
# Epoch 23/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.5972e-04 - pearson_correlation: 0.9958 - val_loss: 1.5474e-04 - val_pearson_correlation: 0.9961
# Epoch 24/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.6868e-04 - pearson_correlation: 0.9956 - val_loss: 1.5854e-04 - val_pearson_correlation: 0.9960
# Epoch 25/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.6816e-04 - pearson_correlation: 0.9956 - val_loss: 1.4978e-04 - val_pearson_correlation: 0.9962
# Epoch 26/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.6071e-04 - pearson_correlation: 0.9958 - val_loss: 1.4920e-04 - val_pearson_correlation: 0.9962
# Epoch 27/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.5866e-04 - pearson_correlation: 0.9959 - val_loss: 1.5894e-04 - val_pearson_correlation: 0.9959
# Epoch 28/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.6857e-04 - pearson_correlation: 0.9956 - val_loss: 1.4845e-04 - val_pearson_correlation: 0.9962
# Epoch 29/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.5845e-04 - pearson_correlation: 0.9959 - val_loss: 1.4896e-04 - val_pearson_correlation: 0.9962
# Epoch 30/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.5640e-04 - pearson_correlation: 0.9959 - val_loss: 1.5937e-04 - val_pearson_correlation: 0.9959
# Epoch 31/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.5804e-04 - pearson_correlation: 0.9959 - val_loss: 1.4724e-04 - val_pearson_correlation: 0.9962
# Epoch 32/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.5471e-04 - pearson_correlation: 0.9959 - val_loss: 1.4718e-04 - val_pearson_correlation: 0.9962
# Epoch 33/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.5665e-04 - pearson_correlation: 0.9959 - val_loss: 1.4786e-04 - val_pearson_correlation: 0.9962
# Epoch 34/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.5662e-04 - pearson_correlation: 0.9959 - val_loss: 1.5317e-04 - val_pearson_correlation: 0.9961
# Epoch 35/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.5732e-04 - pearson_correlation: 0.9959 - val_loss: 1.5488e-04 - val_pearson_correlation: 0.9961
# Epoch 36/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.5098e-04 - pearson_correlation: 0.9960 - val_loss: 1.4510e-04 - val_pearson_correlation: 0.9963
# Epoch 37/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.5709e-04 - pearson_correlation: 0.9959 - val_loss: 1.4622e-04 - val_pearson_correlation: 0.9963
# Epoch 38/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4962e-04 - pearson_correlation: 0.9961 - val_loss: 1.4747e-04 - val_pearson_correlation: 0.9963
# Epoch 39/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4966e-04 - pearson_correlation: 0.9961 - val_loss: 1.4366e-04 - val_pearson_correlation: 0.9964
# Epoch 40/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.4630e-04 - pearson_correlation: 0.9962 - val_loss: 1.5088e-04 - val_pearson_correlation: 0.9962
# Epoch 41/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.5211e-04 - pearson_correlation: 0.9960 - val_loss: 1.4722e-04 - val_pearson_correlation: 0.9963
# Epoch 42/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.5026e-04 - pearson_correlation: 0.9961 - val_loss: 1.5364e-04 - val_pearson_correlation: 0.9960
# Epoch 43/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.5903e-04 - pearson_correlation: 0.9958 - val_loss: 1.4704e-04 - val_pearson_correlation: 0.9963
# Epoch 44/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.4914e-04 - pearson_correlation: 0.9961 - val_loss: 1.4289e-04 - val_pearson_correlation: 0.9964
# Epoch 45/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.4449e-04 - pearson_correlation: 0.9962 - val_loss: 1.4752e-04 - val_pearson_correlation: 0.9963
# Epoch 46/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.5214e-04 - pearson_correlation: 0.9960 - val_loss: 1.3687e-04 - val_pearson_correlation: 0.9965
# Epoch 47/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4422e-04 - pearson_correlation: 0.9962 - val_loss: 1.3700e-04 - val_pearson_correlation: 0.9965
# Epoch 48/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.5545e-04 - pearson_correlation: 0.9959 - val_loss: 1.4218e-04 - val_pearson_correlation: 0.9964
# Epoch 49/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.4398e-04 - pearson_correlation: 0.9962 - val_loss: 1.5249e-04 - val_pearson_correlation: 0.9961
# Epoch 50/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.4590e-04 - pearson_correlation: 0.9962 - val_loss: 1.3844e-04 - val_pearson_correlation: 0.9965
# Epoch 51/148
# 45/45 [==============================] - 6s 124ms/step - loss: 1.4144e-04 - pearson_correlation: 0.9963 - val_loss: 1.4427e-04 - val_pearson_correlation: 0.9964
# Epoch 52/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4374e-04 - pearson_correlation: 0.9963 - val_loss: 1.4067e-04 - val_pearson_correlation: 0.9964
# Epoch 53/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.4140e-04 - pearson_correlation: 0.9963 - val_loss: 1.3782e-04 - val_pearson_correlation: 0.9965
# Epoch 54/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4571e-04 - pearson_correlation: 0.9962 - val_loss: 1.4065e-04 - val_pearson_correlation: 0.9964
# Epoch 55/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.4277e-04 - pearson_correlation: 0.9963 - val_loss: 1.5803e-04 - val_pearson_correlation: 0.9960
# Epoch 56/148
# 45/45 [==============================] - 6s 134ms/step - loss: 1.4913e-04 - pearson_correlation: 0.9961 - val_loss: 1.4374e-04 - val_pearson_correlation: 0.9963
# Epoch 57/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.4272e-04 - pearson_correlation: 0.9963 - val_loss: 1.6009e-04 - val_pearson_correlation: 0.9960
# Epoch 58/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.4148e-04 - pearson_correlation: 0.9963 - val_loss: 1.3901e-04 - val_pearson_correlation: 0.9964
# Epoch 59/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.4289e-04 - pearson_correlation: 0.9963 - val_loss: 1.3559e-04 - val_pearson_correlation: 0.9965
# Epoch 60/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.4541e-04 - pearson_correlation: 0.9962 - val_loss: 1.4364e-04 - val_pearson_correlation: 0.9964
# Epoch 61/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3990e-04 - pearson_correlation: 0.9963 - val_loss: 1.5093e-04 - val_pearson_correlation: 0.9962
# Epoch 62/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3839e-04 - pearson_correlation: 0.9964 - val_loss: 1.3406e-04 - val_pearson_correlation: 0.9966
# Epoch 63/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.3808e-04 - pearson_correlation: 0.9964 - val_loss: 1.3691e-04 - val_pearson_correlation: 0.9965
# Epoch 64/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.3930e-04 - pearson_correlation: 0.9963 - val_loss: 1.3753e-04 - val_pearson_correlation: 0.9965
# Epoch 65/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.4078e-04 - pearson_correlation: 0.9963 - val_loss: 1.5107e-04 - val_pearson_correlation: 0.9961
# Epoch 66/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4476e-04 - pearson_correlation: 0.9962 - val_loss: 1.5872e-04 - val_pearson_correlation: 0.9960
# Epoch 67/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.4728e-04 - pearson_correlation: 0.9962 - val_loss: 1.3936e-04 - val_pearson_correlation: 0.9964
# Epoch 68/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.4161e-04 - pearson_correlation: 0.9963 - val_loss: 1.3710e-04 - val_pearson_correlation: 0.9965
# Epoch 69/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3955e-04 - pearson_correlation: 0.9963 - val_loss: 1.3944e-04 - val_pearson_correlation: 0.9964
# Epoch 70/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.4065e-04 - pearson_correlation: 0.9963 - val_loss: 1.4160e-04 - val_pearson_correlation: 0.9964
# Epoch 71/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3494e-04 - pearson_correlation: 0.9965 - val_loss: 1.3691e-04 - val_pearson_correlation: 0.9965
# Epoch 72/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3405e-04 - pearson_correlation: 0.9965 - val_loss: 1.5124e-04 - val_pearson_correlation: 0.9962
# Epoch 73/148
# 45/45 [==============================] - 7s 153ms/step - loss: 1.4678e-04 - pearson_correlation: 0.9962 - val_loss: 1.6420e-04 - val_pearson_correlation: 0.9960
# Epoch 74/148
# 45/45 [==============================] - 6s 141ms/step - loss: 1.3843e-04 - pearson_correlation: 0.9964 - val_loss: 1.3955e-04 - val_pearson_correlation: 0.9964
# Epoch 75/148
# 45/45 [==============================] - 6s 137ms/step - loss: 1.3102e-04 - pearson_correlation: 0.9966 - val_loss: 1.3777e-04 - val_pearson_correlation: 0.9965
# Epoch 76/148
# 45/45 [==============================] - 7s 165ms/step - loss: 1.3354e-04 - pearson_correlation: 0.9965 - val_loss: 1.4124e-04 - val_pearson_correlation: 0.9964
# Epoch 77/148
# 45/45 [==============================] - 6s 131ms/step - loss: 1.3393e-04 - pearson_correlation: 0.9965 - val_loss: 1.5921e-04 - val_pearson_correlation: 0.9960
# Epoch 78/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3939e-04 - pearson_correlation: 0.9964 - val_loss: 1.4999e-04 - val_pearson_correlation: 0.9962
# Epoch 79/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.4214e-04 - pearson_correlation: 0.9963 - val_loss: 1.3269e-04 - val_pearson_correlation: 0.9968
# Epoch 80/148
# 45/45 [==============================] - 6s 138ms/step - loss: 1.3618e-04 - pearson_correlation: 0.9964 - val_loss: 1.4008e-04 - val_pearson_correlation: 0.9965
# Epoch 81/148
# 45/45 [==============================] - 7s 147ms/step - loss: 1.3350e-04 - pearson_correlation: 0.9965 - val_loss: 1.3153e-04 - val_pearson_correlation: 0.9967
# Epoch 82/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3916e-04 - pearson_correlation: 0.9964 - val_loss: 1.3347e-04 - val_pearson_correlation: 0.9967
# Epoch 83/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.3829e-04 - pearson_correlation: 0.9964 - val_loss: 1.3913e-04 - val_pearson_correlation: 0.9964
# Epoch 84/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.3426e-04 - pearson_correlation: 0.9965 - val_loss: 1.3752e-04 - val_pearson_correlation: 0.9966
# Epoch 85/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3697e-04 - pearson_correlation: 0.9964 - val_loss: 1.3895e-04 - val_pearson_correlation: 0.9965
# Epoch 86/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3297e-04 - pearson_correlation: 0.9965 - val_loss: 1.3189e-04 - val_pearson_correlation: 0.9966
# Epoch 87/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3571e-04 - pearson_correlation: 0.9964 - val_loss: 1.3183e-04 - val_pearson_correlation: 0.9967
# Epoch 88/148
# 45/45 [==============================] - 6s 131ms/step - loss: 1.3333e-04 - pearson_correlation: 0.9965 - val_loss: 1.3454e-04 - val_pearson_correlation: 0.9966
# Epoch 89/148
# 45/45 [==============================] - 6s 131ms/step - loss: 1.3897e-04 - pearson_correlation: 0.9964 - val_loss: 1.5543e-04 - val_pearson_correlation: 0.9962
# Epoch 90/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3849e-04 - pearson_correlation: 0.9964 - val_loss: 1.3234e-04 - val_pearson_correlation: 0.9966
# Epoch 91/148
# 45/45 [==============================] - 6s 132ms/step - loss: 1.3529e-04 - pearson_correlation: 0.9965 - val_loss: 1.4153e-04 - val_pearson_correlation: 0.9964
# Epoch 92/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.3532e-04 - pearson_correlation: 0.9964 - val_loss: 1.3786e-04 - val_pearson_correlation: 0.9965
# Epoch 93/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3412e-04 - pearson_correlation: 0.9965 - val_loss: 1.4022e-04 - val_pearson_correlation: 0.9964
# Epoch 94/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3470e-04 - pearson_correlation: 0.9965 - val_loss: 1.3118e-04 - val_pearson_correlation: 0.9966
# Epoch 95/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3057e-04 - pearson_correlation: 0.9966 - val_loss: 1.3614e-04 - val_pearson_correlation: 0.9965
# Epoch 96/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3563e-04 - pearson_correlation: 0.9965 - val_loss: 1.3032e-04 - val_pearson_correlation: 0.9967
# Epoch 97/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3373e-04 - pearson_correlation: 0.9965 - val_loss: 1.4837e-04 - val_pearson_correlation: 0.9963
# Epoch 98/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3780e-04 - pearson_correlation: 0.9964 - val_loss: 1.3100e-04 - val_pearson_correlation: 0.9967
# Epoch 99/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.3198e-04 - pearson_correlation: 0.9965 - val_loss: 1.3614e-04 - val_pearson_correlation: 0.9965
# Epoch 100/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3546e-04 - pearson_correlation: 0.9965 - val_loss: 1.3108e-04 - val_pearson_correlation: 0.9966
# Epoch 101/148
# 45/45 [==============================] - 6s 125ms/step - loss: 1.3212e-04 - pearson_correlation: 0.9965 - val_loss: 1.3336e-04 - val_pearson_correlation: 0.9966
# Epoch 102/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.3170e-04 - pearson_correlation: 0.9965 - val_loss: 1.3537e-04 - val_pearson_correlation: 0.9966
# Epoch 103/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3484e-04 - pearson_correlation: 0.9965 - val_loss: 1.3058e-04 - val_pearson_correlation: 0.9967
# Epoch 104/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3294e-04 - pearson_correlation: 0.9965 - val_loss: 1.4158e-04 - val_pearson_correlation: 0.9964
# Epoch 105/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3290e-04 - pearson_correlation: 0.9965 - val_loss: 1.3760e-04 - val_pearson_correlation: 0.9965
# Epoch 106/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.4236e-04 - pearson_correlation: 0.9963 - val_loss: 1.3925e-04 - val_pearson_correlation: 0.9964
# Epoch 107/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3275e-04 - pearson_correlation: 0.9965 - val_loss: 1.3764e-04 - val_pearson_correlation: 0.9965
# Epoch 108/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3778e-04 - pearson_correlation: 0.9964 - val_loss: 1.5372e-04 - val_pearson_correlation: 0.9962
# Epoch 109/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3956e-04 - pearson_correlation: 0.9964 - val_loss: 1.4810e-04 - val_pearson_correlation: 0.9963
# Epoch 110/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3875e-04 - pearson_correlation: 0.9964 - val_loss: 1.3759e-04 - val_pearson_correlation: 0.9965
# Epoch 111/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3439e-04 - pearson_correlation: 0.9965 - val_loss: 1.4670e-04 - val_pearson_correlation: 0.9962
# Epoch 112/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3656e-04 - pearson_correlation: 0.9965 - val_loss: 1.4075e-04 - val_pearson_correlation: 0.9964
# Epoch 113/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3466e-04 - pearson_correlation: 0.9965 - val_loss: 1.4209e-04 - val_pearson_correlation: 0.9963
# Epoch 114/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3810e-04 - pearson_correlation: 0.9964 - val_loss: 1.4632e-04 - val_pearson_correlation: 0.9964
# Epoch 115/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3371e-04 - pearson_correlation: 0.9965 - val_loss: 1.4671e-04 - val_pearson_correlation: 0.9963
# Epoch 116/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3717e-04 - pearson_correlation: 0.9964 - val_loss: 1.2833e-04 - val_pearson_correlation: 0.9967
# Epoch 117/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.2954e-04 - pearson_correlation: 0.9966 - val_loss: 1.4399e-04 - val_pearson_correlation: 0.9963
# Epoch 118/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.3247e-04 - pearson_correlation: 0.9965 - val_loss: 1.2865e-04 - val_pearson_correlation: 0.9967
# Epoch 119/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3796e-04 - pearson_correlation: 0.9964 - val_loss: 1.3557e-04 - val_pearson_correlation: 0.9965
# Epoch 120/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.2910e-04 - pearson_correlation: 0.9966 - val_loss: 1.3305e-04 - val_pearson_correlation: 0.9966
# Epoch 121/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3105e-04 - pearson_correlation: 0.9966 - val_loss: 1.3776e-04 - val_pearson_correlation: 0.9965
# Epoch 122/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.2969e-04 - pearson_correlation: 0.9966 - val_loss: 1.3340e-04 - val_pearson_correlation: 0.9967
# Epoch 123/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3026e-04 - pearson_correlation: 0.9966 - val_loss: 1.4172e-04 - val_pearson_correlation: 0.9965
# Epoch 124/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.2797e-04 - pearson_correlation: 0.9967 - val_loss: 1.3233e-04 - val_pearson_correlation: 0.9967
# Epoch 125/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.2805e-04 - pearson_correlation: 0.9967 - val_loss: 1.3683e-04 - val_pearson_correlation: 0.9965
# Epoch 126/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3349e-04 - pearson_correlation: 0.9965 - val_loss: 1.3445e-04 - val_pearson_correlation: 0.9966
# Epoch 127/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.2928e-04 - pearson_correlation: 0.9967 - val_loss: 1.2927e-04 - val_pearson_correlation: 0.9967
# Epoch 128/148
# 45/45 [==============================] - 6s 126ms/step - loss: 1.3069e-04 - pearson_correlation: 0.9966 - val_loss: 1.4140e-04 - val_pearson_correlation: 0.9964
# Epoch 129/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.2718e-04 - pearson_correlation: 0.9967 - val_loss: 1.3720e-04 - val_pearson_correlation: 0.9965
# Epoch 130/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3301e-04 - pearson_correlation: 0.9965 - val_loss: 1.4457e-04 - val_pearson_correlation: 0.9963
# Epoch 131/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.2819e-04 - pearson_correlation: 0.9966 - val_loss: 1.3785e-04 - val_pearson_correlation: 0.9964
# Epoch 132/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3401e-04 - pearson_correlation: 0.9965 - val_loss: 1.6749e-04 - val_pearson_correlation: 0.9958
# Epoch 133/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3270e-04 - pearson_correlation: 0.9965 - val_loss: 1.3531e-04 - val_pearson_correlation: 0.9965
# Epoch 134/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.2755e-04 - pearson_correlation: 0.9966 - val_loss: 1.3166e-04 - val_pearson_correlation: 0.9967
# Epoch 135/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3213e-04 - pearson_correlation: 0.9966 - val_loss: 1.3911e-04 - val_pearson_correlation: 0.9965
# Epoch 136/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.3240e-04 - pearson_correlation: 0.9965 - val_loss: 1.4201e-04 - val_pearson_correlation: 0.9964
# Epoch 137/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.3058e-04 - pearson_correlation: 0.9966 - val_loss: 1.4428e-04 - val_pearson_correlation: 0.9963
# Epoch 138/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3133e-04 - pearson_correlation: 0.9966 - val_loss: 1.3584e-04 - val_pearson_correlation: 0.9966
# Epoch 139/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3076e-04 - pearson_correlation: 0.9966 - val_loss: 1.2845e-04 - val_pearson_correlation: 0.9967
# Epoch 140/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.3004e-04 - pearson_correlation: 0.9966 - val_loss: 1.3400e-04 - val_pearson_correlation: 0.9966
# Epoch 141/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.3241e-04 - pearson_correlation: 0.9966 - val_loss: 1.5212e-04 - val_pearson_correlation: 0.9963
# Epoch 142/148
# 45/45 [==============================] - 6s 130ms/step - loss: 1.4345e-04 - pearson_correlation: 0.9963 - val_loss: 1.3955e-04 - val_pearson_correlation: 0.9965
# Epoch 143/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3285e-04 - pearson_correlation: 0.9965 - val_loss: 1.3689e-04 - val_pearson_correlation: 0.9965
# Epoch 144/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.2990e-04 - pearson_correlation: 0.9966 - val_loss: 1.3088e-04 - val_pearson_correlation: 0.9966
# Epoch 145/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.2631e-04 - pearson_correlation: 0.9967 - val_loss: 1.2547e-04 - val_pearson_correlation: 0.9967
# Epoch 146/148
# 45/45 [==============================] - 6s 128ms/step - loss: 1.2934e-04 - pearson_correlation: 0.9966 - val_loss: 1.2584e-04 - val_pearson_correlation: 0.9968
# Epoch 147/148
# 45/45 [==============================] - 6s 129ms/step - loss: 1.2278e-04 - pearson_correlation: 0.9968 - val_loss: 1.3761e-04 - val_pearson_correlation: 0.9965
# Epoch 148/148
# 45/45 [==============================] - 6s 127ms/step - loss: 1.3046e-04 - pearson_correlation: 0.9966 - val_loss: 1.3867e-04 - val_pearson_correlation: 0.9965
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 35
#      32 currentFoldTrainedModelAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Joint_Abundance_Attention_Model"+str(i+1)+".h5"
#      34 #save the trained model
# ---> 35 trainedModels.append(kAbundanceEstimator)
#      37 break
#
# NameError: name 'kAbundanceEstimator' is not defined

# %%
#predict the abundances
predictedAbundances=jointAbundanceEstimator.predict(preprocessedSpectra[testingIndices,:])
# Out:
# 12/12 [==============================] - 575s 48s/step

# %%
#get the actual abundances for the test samples
actualTestAbundances=allElementalAbundances[testingIndices,:]

# %%
#iterate through all the elements
for i in range(actualTestAbundances.shape[1]):
    #get the actual and predicted abundances for the current element
    currentElementPredictedAbundances=predictedAbundances[:,i]
    currentElementActualAbundances=actualTestAbundances[:,i]
    #compute the correlation between the actual and predicted abundances
    currentElementCorrelation=np.corrcoef(currentElementPredictedAbundances,
                                          currentElementActualAbundances)[0,1]
    #get the name of the current element
    currentElementName=elementNames[i]
    #print the element's name and the correlation between its actual and predicted abundances
    print(f"{currentElementName}--{round(currentElementCorrelation,2)}")
# Out:
# Aluminum--0.82
# Calcium--0.73
# Iron--0.96
# Magnesium--0.85
# Oxygen--0.86
# Silicon--0.84
# Titanium--0.93

# %%
# Out:
# (358, 7)
